# %% [markdown]
# #### Inputs

# %%
import pandas as pd
import numpy as np
import os
import typing
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

from tensorflow.keras.regularizers import l2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsoluteError, MeanSquaredError, MeanSquaredLogarithmicError

from extraction.extract import *
from extraction.extractionvalues import *
from extraction.extractadjacency import getAdjacencyMatrix, distance_weight_adjacency

from sklearn.metrics import mean_absolute_error, mean_squared_error
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# ##### Data parameters

# %%
airports = [
    "EGLL",
    "LFPG",
    "EHAM",
    "EDDF",
    "LEMD",
    "LEBL",
    # "LTFM",
    "UUEE",
    "EDDM",
    "EGKK",
]

n_nodes = n_airports = len(airports)
start = datetime(2018, 3, 1)
end = datetime(2019, 1, 1)
timeslotLength = 60

# Run settings
batch_size = 64
epochs = 1200
patience = 100
input_sequence_length = 4
forecast_horizon = 10
multi_horizon = True

learning_rate = 0.0001
# learning_rate = 0.0005
# learning_rate = 0.005

# %% [markdown]
# ##### Load Data

# %%
dataDict = generateNNdataMultiple(
    airports, timeslotLength, GNNFormat=True, start=start, end=end, disableWeather=True
)
times = list(dataDict.values())[0]["T"]
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 23.81it/s]

# %% [markdown]
# ##### Process Data

# %%
columnsToDrop = [
    "weekend",
    "winter",
    "spring",
    "summer",
    "autumn",
    "night",
    "morning",
    "afternoon",
    "planes",
]
# print(dataDict["EGLL"]["X"].shape)
Xlist = []
Ylist = []
for airport in airports:
    # T x F
    X = dataDict[airport]["X"].drop(columnsToDrop, axis=1).to_numpy()
    Xlist.append(X)

    Y = dataDict[airport]["Y"].iloc[:,:].to_numpy()
    Ylist.append(Y)


Xlist = np.stack(Xlist)
Ylist = np.stack(Ylist)
# N x T x F
Xarray = np.swapaxes(Xlist, 0, 1)
Yarray = np.swapaxes(Ylist, 0, 1)

# Reshape to a flat array that goes arrival then departure delay
# Yarray = np.reshape(Yarray, newshape=[len(times), len(airports)*2], order="F")

# print(Yarray.shape)
# T x N x F

# Normalise over the features
Xmean, Xstd = X.mean(axis=0), X.std(axis=0)
X = (X - Xmean) / Xstd
print("X Mean Shape", Xmean.shape)
Ymean, Ystd = Y.mean(axis=0), Y.std(axis=0)
Y = (Y - Ymean) / Ystd
print("Y Mean Shape", Ymean.shape)

print("T x N x F: ", "Xarray =", Xarray.shape, "|", "Yarray =", Yarray.shape)
# Out:
# X Mean Shape (8,)
# Y Mean Shape (2,)
# T x N x F:  Xarray = (2928, 9, 8) | Yarray = (2928, 9, 2)

# %%
train_split, val_split = 0.6, 0.25

fullLength = len(times)
train_idx = int(train_split * fullLength)
val_idx = int((val_split + train_split) * fullLength)
print(train_idx, val_idx)

Xtrain, Xval, Xtest = Xarray[0:train_idx], Xarray[train_idx:val_idx], Xarray[val_idx::]
Ytrain, Yval, Ytest = Yarray[0:train_idx], Yarray[train_idx:val_idx], Yarray[val_idx::]
# Out:
# 1756 2488

# %% [markdown]
# ##### Create tensorflow dataset

# %%
def create_tf_dataset(
    data_array: np.ndarray,
    target_array,
    input_sequence_length: int,
    forecast_horizon: int,
    batch_size: int = 128,
    shuffle=True,
    multi_horizon=False,
):
    """Creates tensorflow dataset from numpy array.

    This function creates a dataset where each element is a tuple `(inputs, targets)`.
    `inputs` is a Tensor
    of shape `(batch_size, input_sequence_length, num_routes, 1)` containing
    the `input_sequence_length` past values of the timeseries for each node.
    `targets` is a Tensor of shape `(batch_size, forecast_horizon, num_routes)`
    containing the `forecast_horizon`
    future values of the timeseries for each node.

    Args:
        data_array: np.ndarray with shape `(num_time_steps, num_routes)`
        input_sequence_length: Length of the input sequence (in number of timesteps).
        forecast_horizon: If `multi_horizon=True`, the target will be the values of the timeseries for 1 to
            `forecast_horizon` timesteps ahead. If `multi_horizon=False`, the target will be the value of the
            timeseries `forecast_horizon` steps ahead (only one value).
        batch_size: Number of timeseries samples in each batch.
        shuffle: Whether to shuffle output samples, or instead draw them in chronological order.
        multi_horizon: See `forecast_horizon`.

    Returns:
        A tf.data.Dataset instance.
    """

    inputs = timeseries_dataset_from_array(
        data_array[:-forecast_horizon],
        None,
        sequence_length=input_sequence_length,
        shuffle=False,
        batch_size=batch_size,
    )

    dataset = inputs
    target_offset = (
        input_sequence_length
        if multi_horizon
        else input_sequence_length + forecast_horizon - 1
    )
    target_seq_length = forecast_horizon if multi_horizon else 1
    targets = timeseries_dataset_from_array(
        target_array[target_offset:],
        None,
        sequence_length=target_seq_length,
        shuffle=False,
        batch_size=batch_size,
    )

    dataset = tf.data.Dataset.zip((inputs, targets))
    if shuffle:
        dataset = dataset.shuffle(100)

    return dataset.prefetch(16).cache()


train_dataset = create_tf_dataset(
    Xtrain,
    Ytrain,
    input_sequence_length,
    forecast_horizon,
    batch_size=batch_size,
    shuffle=False,
    multi_horizon=multi_horizon,
)

val_dataset = create_tf_dataset(
    Xval,
    Yval,
    input_sequence_length,
    forecast_horizon,
    batch_size=batch_size,
    shuffle=False,
    multi_horizon=multi_horizon,
)
test_dataset = create_tf_dataset(
    Xtest,
    Ytest,
    input_sequence_length,
    forecast_horizon,
    batch_size=batch_size,
    shuffle=False,
    multi_horizon=multi_horizon,
)

print(train_dataset)
# Out:
# <CacheDataset shapes: ((None, None, 9, 8), (None, None, 9, 2)), types: (tf.float64, tf.float64)>

# %% [markdown]
# # Adjacency Matrix

# %%
class GraphInfo:
    def __init__(self, edges: typing.Tuple[list, list], num_nodes: int):
        self.edges = edges
        self.num_nodes = num_nodes


distance_adj = distance_weight_adjacency(
    airports, threshold=400
)  # getAdjacencyMatrix(airports)[10]
# flight_adj = np.mean(
#     getAdjacencyMatrix(airports, start, end, timeslotLength), axis=0)
flight_adj = np.array(
    [
        [
            0.0,
            0.06728142076502733,
            0.07493169398907065,
            0.11737249544626573,
            0.08731785063752331,
            0.08691939890710383,
            0.05976775956284153,
            0.09995446265938075,
            0.00034153005464480874,
        ],
        [
            0.09221311475409882,
            0.0,
            0.07809653916211337,
            0.08891165755919873,
            0.06819216757741367,
            0.07900728597449944,
            0.09375,
            0.11372950819672131,
            0.052424863387978145,
        ],
        [
            0.09153005464480875,
            0.11270491803278689,
            0.0,
            0.07729963570127565,
            0.08965163934426229,
            0.0782103825136618,
            0.05140027322404372,
            0.07627504553734095,
            0.06841985428051031,
        ],
        [
            0.08760245901639344,
            0.08822859744990921,
            0.07821038251366169,
            0.0,
            0.07320127504553768,
            0.05794626593806932,
            0.0469603825136612,
            0.09301001821493657,
            0.0006830601092896175,
        ],
        [
            0.0875455373406198,
            0.06830601092896188,
            0.09187158469945356,
            0.07308743169398944,
            0.0,
            0.0933060109289611,
            0.05225409836065574,
            0.0617030965391622,
            0.06545992714025516,
        ],
        [
            0.08691939890710383,
            0.08014571948998225,
            0.07946265938069258,
            0.08709016393442623,
            0.09323770491803217,
            0.0,
            0.04337431693989071,
            0.08504098360655737,
            0.10040983606557388,
        ],
        [
            0.039731329690346005,
            0.06193078324225894,
            0.05140027322404372,
            0.08299180327868852,
            0.05157103825136612,
            0.08572404371584699,
            0.0,
            0.08265027322404371,
            0.0,
        ],
        [
            0.100068306010929,
            0.11321721311475409,
            0.07877959927140268,
            0.0943761384335157,
            0.09170081967213115,
            0.08487021857923498,
            0.08333333333333333,
            0.0,
            0.05362021857923497,
        ],
        [
            0.0006830601092896175,
            0.05259562841530055,
            0.07081056466302399,
            0.0,
            0.06534608378870696,
            0.10029599271402556,
            0.0,
            0.05430327868852459,
            0.0,
        ],
    ]
)
adjacency_matrix = distance_adj * 0.4 + (1 - 0.4) * flight_adj
# adjacency_matrix = distance_adj
# adjacency_matrix = np.ones((10,10))/2
# print(adjacency_matrix.shape)
# print(adjacency_matrix)
node_indices, neighbor_indices = np.where(adjacency_matrix != 0)
graph = GraphInfo(
    edges=(node_indices.tolist(), neighbor_indices.tolist()),
    num_nodes=adjacency_matrix.shape[0],
)
# print(adjacency_matrix)
# # print(adjacency_matrix.shape)
# print(np.where(adjacency_matrix != 0))
# print(np.where(adjacency_matrix != 0).shape)

# %%
print(flight_adj.shape)
# Out:
# (9, 9)

# %%
plt.imshow(adjacency_matrix)
plt.xticks(range(len(airports)), airports, fontsize=12, rotation=-90)
plt.yticks(range(len(airports)), airports, fontsize=12, rotation=0)
plt.show()

# %% [markdown]
# ## Graph Convolution Layer

# %%
class GraphConv(layers.Layer):
    def __init__(
        self,
        in_feat,
        out_feat,
        graph_info: GraphInfo,
        aggregation_type="mean",
        combination_type="concat",
        activation: typing.Optional[str] = None,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.graph_info = graph_info

        self.aggregation_type = aggregation_type
        self.combination_type = combination_type
        self.weight = tf.Variable(
            initial_value=keras.initializers.glorot_uniform()(
                shape=(in_feat, out_feat), dtype="float32"
            ),
            trainable=True,
        )
        self.activation = layers.Activation(activation)

    def aggregate(self, neighbour_representations: tf.Tensor):
        aggregation_func = {
            "sum": tf.math.unsorted_segment_sum,
            "mean": tf.math.unsorted_segment_mean,
            "max": tf.math.unsorted_segment_max,
        }.get(self.aggregation_type)

        if aggregation_func:
            return aggregation_func(
                neighbour_representations,
                self.graph_info.edges[0],
                num_segments=self.graph_info.num_nodes,
            )

        raise ValueError(f"Invalid aggregation type: {self.aggregation_type}")

    def compute_nodes_representation(self, features: tf.Tensor):
        """Computes each node's representation.

        The nodes' representations are obtained by multiplying the features tensor with
        `self.weight`. Note that
        `self.weight` has shape `(in_feat, out_feat)`.

        Args:
            features: Tensor of shape `(num_nodes, batch_size, input_seq_len, in_feat)`

        Returns:
            A tensor of shape `(num_nodes, batch_size, input_seq_len, out_feat)`
        """
        return tf.matmul(features, self.weight)

    def compute_aggregated_messages(self, features: tf.Tensor):
        neighbour_representations = tf.gather(features, self.graph_info.edges[1])
        aggregated_messages = self.aggregate(neighbour_representations)
        return tf.matmul(aggregated_messages, self.weight)

    def update(self, nodes_representation: tf.Tensor, aggregated_messages: tf.Tensor):
        if self.combination_type == "concat":
            h = tf.concat([nodes_representation, aggregated_messages], axis=-1)
        elif self.combination_type == "add":
            h = nodes_representation + aggregated_messages
        else:
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        return self.activation(h)

    def call(self, features: tf.Tensor):
        """Forward pass.

        Args:
            features: tensor of shape `(num_nodes, batch_size, input_seq_len, in_feat)`

        Returns:
            A tensor of shape `(num_nodes, batch_size, input_seq_len, out_feat)`
        """
        nodes_representation = self.compute_nodes_representation(features)
        aggregated_messages = self.compute_aggregated_messages(features)
        return self.update(nodes_representation, aggregated_messages)

# %% [markdown]
# ## LSTM including graph convolution layer

# %%
class LSTMGC(layers.Layer):
    """Layer comprising a convolution layer followed by LSTM and dense layers."""

    def __init__(
        self,
        in_feat,
        out_feat,
        lstm_units: int,
        input_seq_len: int,
        # output_seq_len: int,
        graph_info: GraphInfo,
        graph_conv_params: typing.Optional[dict] = None,
        num_labels:int = 2,
        multi_horizon: int = True,
        forecast_horizon: int = forecast_horizon,
        **kwargs,
    ):

        if multi_horizon:
            self.forecast_horizon = forecast_horizon
        else:
            self.forecast_horizon = 1

        self.in_feat = in_feat
        self.out_feat = out_feat
        self.lstm_units = lstm_units
        self.input_seq_len = input_seq_len
        # self.output_seq_len = output_seq_len
        self.graph_info = graph_info
        self.graph_conv_params = graph_conv_params
        self.multi_horizon = multi_horizon
        self.num_labels = num_labels
        super().__init__(**kwargs)

        # graph conv layer
        if graph_conv_params is None:
            graph_conv_params = {
                "aggregation_type": "mean",
                "combination_type": "concat",
                "activation": None,
            }


        # Layer definitions
        self.graph_conv = GraphConv(in_feat, out_feat, graph_info, **graph_conv_params)
        self.graph_conv2 = GraphConv(in_feat, out_feat, graph_info, **graph_conv_params)
        l2_reg = 2.5e-4  # L2 regularization rate

        self.lstm1 = layers.LSTM(
            lstm_units,
            return_sequences=True,
            activation="tanh",
            dropout=0.2,
            kernel_regularizer=l2(l2_reg),
            activity_regularizer=l2(l2_reg),
            bias_regularizer=l2(l2_reg),
        )
        self.lstm2 = layers.LSTM(
            lstm_units,
            activation="tanh",
            dropout=0.2,
            kernel_regularizer=l2(l2_reg),
            activity_regularizer=l2(l2_reg),
            bias_regularizer=l2(l2_reg),
        )
        # self.dense = layers.Dense(output_seq_len)
        self.denseThick = layers.Dense(128)
        self.denseThick2 = layers.Dense(64)
        self.denseThick3 = layers.Dense(16)
        self.dense = layers.Dense(self.forecast_horizon * self.num_labels)

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "in_feat": self.in_feat,
                "out_feat": self.out_feat,
                "lstm_units": self.lstm_units,
                "input_seq_len": self.input_seq_len,
                "graph_info": self.graph_info,
                "graph_conv_params": self.graph_conv_params,
            }
        )
        return config

    def call(self, inputs):
        """Forward pass.

        Args:
            inputs: tf.Tensor of shape `(batch_size, input_seq_len, num_nodes, in_feat)`

        Returns:
            A tensor of shape `(batch_size, output_seq_len, num_nodes)`.
        """

        # convert shape to  (num_nodes, batch_size, input_seq_len, in_feat)
        inputs = tf.transpose(inputs, [2, 0, 1, 3])
        gcn_out = self.graph_conv(inputs)

        # print(f"The GCN output shape  = {gcn_out}")
        shape = tf.shape(gcn_out)
        num_nodes, batch_size, input_seq_len, out_feat = (
            shape[0],
            shape[1],
            shape[2],
            shape[3],
        )
        # LSTM takes only 3D tensors as input
        gcn_out = tf.reshape(gcn_out, (batch_size * num_nodes, input_seq_len, out_feat))
        # print(f"The input shape for the LSTM is {gcn_out}")
        lstmLayer1 = self.lstm1(
            gcn_out
        )  # lstm_out has shape: (batch_size * num_nodes, lstm_units)
        lstmLayer2 = self.lstm2(
            lstmLayer1
        ) 
        dense_1 = self.denseThick(lstmLayer2)
        dense_2 = self.denseThick2(dense_1)
        dense_3 = self.denseThick3(dense_2)

        dense_output = self.dense(dense_3)
        # dense_output has shape: (batch_size * num_nodes, multi_thing*2)

        output = tf.reshape(dense_output, (num_nodes, batch_size, self.forecast_horizon , self.num_labels))
        final = tf.transpose(output, [1, 2, 0, 3])
        return final
        # # returns Tensor of shape (batch_size, forecast_horizon, num_nodes, nlabels)

# %% [markdown]
# ## Training the model

# %%
in_feat = Xarray.shape[2]

out_feat = 15
lstm_units = 128
graph_conv_params = {
    "aggregation_type": "mean",
    "combination_type": "concat",
    "activation": None,
}

st_gcn = LSTMGC(
    in_feat = in_feat,
    out_feat = out_feat,
    lstm_units = lstm_units,
    input_seq_len = input_sequence_length,
    graph_info = graph,
    graph_conv_params = graph_conv_params,
    num_labels = 2,
    multi_horizon = multi_horizon,
    forecast_horizon = forecast_horizon ,
)


inputs = layers.Input(
    (input_sequence_length, graph.num_nodes, in_feat)
)# , batch_size=batch_size)
outputs = st_gcn(inputs)

model = keras.models.Model(inputs, outputs)

optimizer = Adam(learning_rate=learning_rate)
model.compile(
    optimizer=optimizer,
    loss=MeanSquaredLogarithmicError(reduction="auto", name="mean_absolute_error"),
    weighted_metrics=["acc"],
)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 4, 9, 8)]         0
#
#  lstmgc_1 (LSTMGC)           (None, 10, 9, 2)          239380
#
# =================================================================
# Total params: 239,380
# Trainable params: 239,380
# Non-trainable params: 0
# _________________________________________________________________

# %%
log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[keras.callbacks.EarlyStopping(patience=patience), tensorboard_callback],
)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Unable to serialize <__main__.GraphInfo object at 0x000002D681CC6D60> to JSON. Unrecognized type <class '__main__.GraphInfo'>.
# Epoch 1/1200
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 28/28 [==============================] - 9s 92ms/step - loss: 3.4862 - acc: 0.4983 - val_loss: 2.6070 - val_acc: 0.5131
# Epoch 2/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 2.6633 - acc: 0.5126 - val_loss: 2.0701 - val_acc: 0.5160
# Epoch 3/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 1.9231 - acc: 0.5130 - val_loss: 1.6781 - val_acc: 0.5000
# Epoch 4/1200
# 28/28 [==============================] - 1s 33ms/step - loss: 1.7020 - acc: 0.5079 - val_loss: 1.6979 - val_acc: 0.5120
# Epoch 5/1200
# 28/28 [==============================] - 1s 32ms/step - loss: 1.6891 - acc: 0.5024 - val_loss: 1.6692 - val_acc: 0.5087
# Epoch 6/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 1.6718 - acc: 0.5127 - val_loss: 1.6500 - val_acc: 0.5301
# Epoch 7/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 1.6574 - acc: 0.5231 - val_loss: 1.6373 - val_acc: 0.5339
# Epoch 8/1200
# 28/28 [==============================] - 1s 33ms/step - loss: 1.6451 - acc: 0.5284 - val_loss: 1.6255 - val_acc: 0.5333
# Epoch 9/1200
# 28/28 [==============================] - 1s 39ms/step - loss: 1.6353 - acc: 0.5321 - val_loss: 1.6106 - val_acc: 0.5325
# Epoch 10/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 1.6236 - acc: 0.5331 - val_loss: 1.5955 - val_acc: 0.5319
# Epoch 11/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 1.6155 - acc: 0.5340 - val_loss: 1.5799 - val_acc: 0.5318
# Epoch 12/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.6059 - acc: 0.5350 - val_loss: 1.5637 - val_acc: 0.5320
# Epoch 13/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.6001 - acc: 0.5357 - val_loss: 1.5484 - val_acc: 0.5324
# Epoch 14/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5920 - acc: 0.5370 - val_loss: 1.5372 - val_acc: 0.5340
# Epoch 15/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.5859 - acc: 0.5416 - val_loss: 1.5265 - val_acc: 0.5387
# Epoch 16/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5799 - acc: 0.5472 - val_loss: 1.5195 - val_acc: 0.5480
# Epoch 17/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5745 - acc: 0.5537 - val_loss: 1.5119 - val_acc: 0.5550
# Epoch 18/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5694 - acc: 0.5608 - val_loss: 1.5056 - val_acc: 0.5605
# Epoch 19/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5650 - acc: 0.5645 - val_loss: 1.5012 - val_acc: 0.5681
# Epoch 20/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5593 - acc: 0.5676 - val_loss: 1.4942 - val_acc: 0.5693
# Epoch 21/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5565 - acc: 0.5690 - val_loss: 1.4888 - val_acc: 0.5689
# Epoch 22/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 1.5522 - acc: 0.5689 - val_loss: 1.4862 - val_acc: 0.5684
# Epoch 23/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5478 - acc: 0.5689 - val_loss: 1.4811 - val_acc: 0.5683
# Epoch 24/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5455 - acc: 0.5683 - val_loss: 1.4793 - val_acc: 0.5674
# Epoch 25/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5425 - acc: 0.5682 - val_loss: 1.4776 - val_acc: 0.5645
# Epoch 26/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5398 - acc: 0.5677 - val_loss: 1.4750 - val_acc: 0.5614
# Epoch 27/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5360 - acc: 0.5683 - val_loss: 1.4728 - val_acc: 0.5666
# Epoch 28/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5337 - acc: 0.5706 - val_loss: 1.4707 - val_acc: 0.5697
# Epoch 29/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.5299 - acc: 0.5728 - val_loss: 1.4690 - val_acc: 0.5708
# Epoch 30/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5285 - acc: 0.5740 - val_loss: 1.4665 - val_acc: 0.5712
# Epoch 31/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.5250 - acc: 0.5759 - val_loss: 1.4646 - val_acc: 0.5722
# Epoch 32/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 1.5222 - acc: 0.5768 - val_loss: 1.4642 - val_acc: 0.5730
# Epoch 33/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5196 - acc: 0.5771 - val_loss: 1.4624 - val_acc: 0.5735
# Epoch 34/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.5189 - acc: 0.5775 - val_loss: 1.4579 - val_acc: 0.5737
# Epoch 35/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 1.5151 - acc: 0.5779 - val_loss: 1.4553 - val_acc: 0.5738
# Epoch 36/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5151 - acc: 0.5780 - val_loss: 1.4538 - val_acc: 0.5743
# Epoch 37/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5124 - acc: 0.5784 - val_loss: 1.4500 - val_acc: 0.5744
# Epoch 38/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.5091 - acc: 0.5785 - val_loss: 1.4497 - val_acc: 0.5745
# Epoch 39/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5078 - acc: 0.5789 - val_loss: 1.4467 - val_acc: 0.5750
# Epoch 40/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.5064 - acc: 0.5790 - val_loss: 1.4440 - val_acc: 0.5756
# Epoch 41/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.5036 - acc: 0.5799 - val_loss: 1.4432 - val_acc: 0.5758
# Epoch 42/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.5020 - acc: 0.5795 - val_loss: 1.4401 - val_acc: 0.5770
# Epoch 43/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4986 - acc: 0.5799 - val_loss: 1.4358 - val_acc: 0.5778
# Epoch 44/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4975 - acc: 0.5806 - val_loss: 1.4325 - val_acc: 0.5785
# Epoch 45/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4938 - acc: 0.5809 - val_loss: 1.4304 - val_acc: 0.5803
# Epoch 46/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4901 - acc: 0.5819 - val_loss: 1.4258 - val_acc: 0.5815
# Epoch 47/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4866 - acc: 0.5827 - val_loss: 1.4214 - val_acc: 0.5815
# Epoch 48/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4842 - acc: 0.5837 - val_loss: 1.4177 - val_acc: 0.5828
# Epoch 49/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.4813 - acc: 0.5841 - val_loss: 1.4158 - val_acc: 0.5832
# Epoch 50/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4750 - acc: 0.5850 - val_loss: 1.4103 - val_acc: 0.5835
# Epoch 51/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4728 - acc: 0.5853 - val_loss: 1.4081 - val_acc: 0.5804
# Epoch 52/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4684 - acc: 0.5864 - val_loss: 1.4045 - val_acc: 0.5794
# Epoch 53/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4660 - acc: 0.5871 - val_loss: 1.4011 - val_acc: 0.5800
# Epoch 54/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.4609 - acc: 0.5874 - val_loss: 1.3962 - val_acc: 0.5807
# Epoch 55/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 1.4577 - acc: 0.5880 - val_loss: 1.3933 - val_acc: 0.5811
# Epoch 56/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 1.4527 - acc: 0.5889 - val_loss: 1.3874 - val_acc: 0.5822
# Epoch 57/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 1.4122 - acc: 0.5867 - val_loss: 1.3436 - val_acc: 0.5690
# Epoch 58/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.3566 - acc: 0.5809 - val_loss: 1.3099 - val_acc: 0.5792
# Epoch 59/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.3399 - acc: 0.5904 - val_loss: 1.2945 - val_acc: 0.5827
# Epoch 60/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.3302 - acc: 0.5895 - val_loss: 1.2845 - val_acc: 0.5830
# Epoch 61/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.3216 - acc: 0.5899 - val_loss: 1.2800 - val_acc: 0.5839
# Epoch 62/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.3179 - acc: 0.5895 - val_loss: 1.2769 - val_acc: 0.5849
# Epoch 63/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.3132 - acc: 0.5904 - val_loss: 1.2721 - val_acc: 0.5856
# Epoch 64/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 1.3081 - acc: 0.5905 - val_loss: 1.2709 - val_acc: 0.5865
# Epoch 65/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.3056 - acc: 0.5917 - val_loss: 1.2655 - val_acc: 0.5871
# Epoch 66/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.3013 - acc: 0.5915 - val_loss: 1.2646 - val_acc: 0.5880
# Epoch 67/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2969 - acc: 0.5930 - val_loss: 1.2621 - val_acc: 0.5891
# Epoch 68/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 1.2950 - acc: 0.5934 - val_loss: 1.2596 - val_acc: 0.5894
# Epoch 69/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 1.2907 - acc: 0.5953 - val_loss: 1.2585 - val_acc: 0.5899
# Epoch 70/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2889 - acc: 0.5950 - val_loss: 1.2570 - val_acc: 0.5906
# Epoch 71/1200
# 28/28 [==============================] - 1s 29ms/step - loss: 1.2863 - acc: 0.5976 - val_loss: 1.2546 - val_acc: 0.5924
# Epoch 72/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.2843 - acc: 0.5982 - val_loss: 1.2527 - val_acc: 0.5931
# Epoch 73/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 1.2806 - acc: 0.5981 - val_loss: 1.2508 - val_acc: 0.5938
# Epoch 74/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 1.2794 - acc: 0.5979 - val_loss: 1.2483 - val_acc: 0.5956
# Epoch 75/1200
# 28/28 [==============================] - 1s 35ms/step - loss: 1.2744 - acc: 0.5997 - val_loss: 1.2456 - val_acc: 0.5962
# Epoch 76/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 1.2735 - acc: 0.5997 - val_loss: 1.2461 - val_acc: 0.5978
# Epoch 77/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 1.2740 - acc: 0.6010 - val_loss: 1.2448 - val_acc: 0.5992
# Epoch 78/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 1.2712 - acc: 0.6020 - val_loss: 1.2431 - val_acc: 0.6000
# Epoch 79/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 1.2663 - acc: 0.6033 - val_loss: 1.2409 - val_acc: 0.6014
# Epoch 80/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 1.2647 - acc: 0.6041 - val_loss: 1.2390 - val_acc: 0.6032
# Epoch 81/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.2664 - acc: 0.6036 - val_loss: 1.2365 - val_acc: 0.6029
# Epoch 82/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.2637 - acc: 0.6044 - val_loss: 1.2343 - val_acc: 0.6040
# Epoch 83/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2593 - acc: 0.6055 - val_loss: 1.2323 - val_acc: 0.6057
# Epoch 84/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2575 - acc: 0.6052 - val_loss: 1.2324 - val_acc: 0.6062
# Epoch 85/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 1.2583 - acc: 0.6051 - val_loss: 1.2315 - val_acc: 0.6070
# Epoch 86/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2565 - acc: 0.6056 - val_loss: 1.2289 - val_acc: 0.6080
# Epoch 87/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2540 - acc: 0.6087 - val_loss: 1.2271 - val_acc: 0.6088
# Epoch 88/1200
# 28/28 [==============================] - 1s 27ms/step - loss: 1.2518 - acc: 0.6074 - val_loss: 1.2248 - val_acc: 0.6094
# Epoch 89/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2507 - acc: 0.6077 - val_loss: 1.2234 - val_acc: 0.6104
# Epoch 90/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2490 - acc: 0.6080 - val_loss: 1.2208 - val_acc: 0.6113
# Epoch 91/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2460 - acc: 0.6086 - val_loss: 1.2226 - val_acc: 0.6111
# Epoch 92/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 1.2459 - acc: 0.6098 - val_loss: 1.2192 - val_acc: 0.6118
# Epoch 93/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 1.2430 - acc: 0.6102 - val_loss: 1.2189 - val_acc: 0.6114
# Epoch 94/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 1.2427 - acc: 0.6090 - val_loss: 1.2184 - val_acc: 0.6124
# Epoch 95/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 1.2412 - acc: 0.6108 - val_loss: 1.2164 - val_acc: 0.6125
# Epoch 96/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.2393 - acc: 0.6111 - val_loss: 1.2144 - val_acc: 0.6132
# Epoch 97/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.2357 - acc: 0.6109 - val_loss: 1.2142 - val_acc: 0.6137
# Epoch 98/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.2370 - acc: 0.6132 - val_loss: 1.2129 - val_acc: 0.6142
# Epoch 99/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 1.2346 - acc: 0.6139 - val_loss: 1.2096 - val_acc: 0.6149
# Epoch 100/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2335 - acc: 0.6135 - val_loss: 1.2088 - val_acc: 0.6160
# Epoch 101/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2319 - acc: 0.6138 - val_loss: 1.2077 - val_acc: 0.6163
# Epoch 102/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2277 - acc: 0.6145 - val_loss: 1.2055 - val_acc: 0.6161
# Epoch 103/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2298 - acc: 0.6139 - val_loss: 1.2026 - val_acc: 0.6175
# Epoch 104/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2275 - acc: 0.6145 - val_loss: 1.2008 - val_acc: 0.6180
# Epoch 105/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2243 - acc: 0.6168 - val_loss: 1.2017 - val_acc: 0.6184
# Epoch 106/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2240 - acc: 0.6157 - val_loss: 1.2023 - val_acc: 0.6182
# Epoch 107/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2215 - acc: 0.6167 - val_loss: 1.2003 - val_acc: 0.6191
# Epoch 108/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2214 - acc: 0.6168 - val_loss: 1.1947 - val_acc: 0.6199
# Epoch 109/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2179 - acc: 0.6170 - val_loss: 1.1952 - val_acc: 0.6211
# Epoch 110/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2177 - acc: 0.6190 - val_loss: 1.1925 - val_acc: 0.6216
# Epoch 111/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2158 - acc: 0.6200 - val_loss: 1.1921 - val_acc: 0.6227
# Epoch 112/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2134 - acc: 0.6195 - val_loss: 1.1897 - val_acc: 0.6222
# Epoch 113/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2118 - acc: 0.6209 - val_loss: 1.1914 - val_acc: 0.6253
# Epoch 114/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2114 - acc: 0.6214 - val_loss: 1.1853 - val_acc: 0.6248
# Epoch 115/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2066 - acc: 0.6235 - val_loss: 1.1889 - val_acc: 0.6237
# Epoch 116/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2084 - acc: 0.6231 - val_loss: 1.1839 - val_acc: 0.6291
# Epoch 117/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2053 - acc: 0.6240 - val_loss: 1.1794 - val_acc: 0.6304
# Epoch 118/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.2030 - acc: 0.6256 - val_loss: 1.1813 - val_acc: 0.6318
# Epoch 119/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.2015 - acc: 0.6260 - val_loss: 1.1769 - val_acc: 0.6312
# Epoch 120/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.1986 - acc: 0.6278 - val_loss: 1.1740 - val_acc: 0.6324
# Epoch 121/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1944 - acc: 0.6270 - val_loss: 1.1734 - val_acc: 0.6352
# Epoch 122/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1944 - acc: 0.6287 - val_loss: 1.1709 - val_acc: 0.6361
# Epoch 123/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 1.1900 - acc: 0.6291 - val_loss: 1.1732 - val_acc: 0.6355
# Epoch 124/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1895 - acc: 0.6312 - val_loss: 1.1685 - val_acc: 0.6372
# Epoch 125/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1892 - acc: 0.6317 - val_loss: 1.1662 - val_acc: 0.6377
# Epoch 126/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1855 - acc: 0.6340 - val_loss: 1.1646 - val_acc: 0.6388
# Epoch 127/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1846 - acc: 0.6354 - val_loss: 1.1607 - val_acc: 0.6395
# Epoch 128/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.1821 - acc: 0.6347 - val_loss: 1.1606 - val_acc: 0.6398
# Epoch 129/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1793 - acc: 0.6372 - val_loss: 1.1569 - val_acc: 0.6420
# Epoch 130/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1788 - acc: 0.6362 - val_loss: 1.1525 - val_acc: 0.6429
# Epoch 131/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1739 - acc: 0.6371 - val_loss: 1.1521 - val_acc: 0.6434
# Epoch 132/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 1.1736 - acc: 0.6383 - val_loss: 1.1477 - val_acc: 0.6455
# Epoch 133/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1709 - acc: 0.6388 - val_loss: 1.1501 - val_acc: 0.6449
# Epoch 134/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 1.1693 - acc: 0.6402 - val_loss: 1.1448 - val_acc: 0.6465
# Epoch 135/1200
# 28/28 [==============================] - 1s 28ms/step - loss: 1.1668 - acc: 0.6409 - val_loss: 1.1422 - val_acc: 0.6467
# Epoch 136/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1628 - acc: 0.6419 - val_loss: 1.1414 - val_acc: 0.6457
# Epoch 137/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1642 - acc: 0.6430 - val_loss: 1.1392 - val_acc: 0.6474
# Epoch 138/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1602 - acc: 0.6432 - val_loss: 1.1363 - val_acc: 0.6485
# Epoch 139/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1599 - acc: 0.6439 - val_loss: 1.1332 - val_acc: 0.6496
# Epoch 140/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1592 - acc: 0.6435 - val_loss: 1.1341 - val_acc: 0.6497
# Epoch 141/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1552 - acc: 0.6449 - val_loss: 1.1278 - val_acc: 0.6505
# Epoch 142/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1497 - acc: 0.6471 - val_loss: 1.1283 - val_acc: 0.6503
# Epoch 143/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 1.1509 - acc: 0.6470 - val_loss: 1.1272 - val_acc: 0.6517
# Epoch 144/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.1482 - acc: 0.6471 - val_loss: 1.1228 - val_acc: 0.6527
# Epoch 145/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1477 - acc: 0.6496 - val_loss: 1.1209 - val_acc: 0.6528
# Epoch 146/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1445 - acc: 0.6507 - val_loss: 1.1181 - val_acc: 0.6542
# Epoch 147/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1386 - acc: 0.6502 - val_loss: 1.1155 - val_acc: 0.6540
# Epoch 148/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1408 - acc: 0.6500 - val_loss: 1.1158 - val_acc: 0.6544
# Epoch 149/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1416 - acc: 0.6517 - val_loss: 1.1118 - val_acc: 0.6542
# Epoch 150/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1376 - acc: 0.6524 - val_loss: 1.1090 - val_acc: 0.6557
# Epoch 151/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1340 - acc: 0.6527 - val_loss: 1.1060 - val_acc: 0.6565
# Epoch 152/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1301 - acc: 0.6539 - val_loss: 1.1062 - val_acc: 0.6558
# Epoch 153/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1316 - acc: 0.6527 - val_loss: 1.1078 - val_acc: 0.6562
# Epoch 154/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.1309 - acc: 0.6535 - val_loss: 1.0995 - val_acc: 0.6570
# Epoch 155/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1260 - acc: 0.6526 - val_loss: 1.1004 - val_acc: 0.6571
# Epoch 156/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1239 - acc: 0.6557 - val_loss: 1.0959 - val_acc: 0.6581
# Epoch 157/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1211 - acc: 0.6560 - val_loss: 1.0915 - val_acc: 0.6589
# Epoch 158/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1216 - acc: 0.6550 - val_loss: 1.0909 - val_acc: 0.6602
# Epoch 159/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 1.1208 - acc: 0.6557 - val_loss: 1.0920 - val_acc: 0.6609
# Epoch 160/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.1196 - acc: 0.6566 - val_loss: 1.0872 - val_acc: 0.6608
# Epoch 161/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1145 - acc: 0.6549 - val_loss: 1.0910 - val_acc: 0.6615
# Epoch 162/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 1.1159 - acc: 0.6570 - val_loss: 1.0856 - val_acc: 0.6609
# Epoch 163/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1125 - acc: 0.6586 - val_loss: 1.0876 - val_acc: 0.6623
# Epoch 164/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1138 - acc: 0.6594 - val_loss: 1.0806 - val_acc: 0.6624
# Epoch 165/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1103 - acc: 0.6580 - val_loss: 1.0799 - val_acc: 0.6638
# Epoch 166/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1074 - acc: 0.6593 - val_loss: 1.0760 - val_acc: 0.6633
# Epoch 167/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1045 - acc: 0.6597 - val_loss: 1.0732 - val_acc: 0.6631
# Epoch 168/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.1036 - acc: 0.6609 - val_loss: 1.0727 - val_acc: 0.6635
# Epoch 169/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.1021 - acc: 0.6583 - val_loss: 1.0704 - val_acc: 0.6652
# Epoch 170/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 1.0999 - acc: 0.6609 - val_loss: 1.0687 - val_acc: 0.6642
# Epoch 171/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.0968 - acc: 0.6624 - val_loss: 1.0648 - val_acc: 0.6638
# Epoch 172/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.0945 - acc: 0.6616 - val_loss: 1.0643 - val_acc: 0.6649
# Epoch 173/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 1.0930 - acc: 0.6636 - val_loss: 1.0604 - val_acc: 0.6647
# Epoch 174/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 1.0889 - acc: 0.6607 - val_loss: 1.0545 - val_acc: 0.6632
# Epoch 175/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0820 - acc: 0.6612 - val_loss: 1.0558 - val_acc: 0.6627
# Epoch 176/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0821 - acc: 0.6615 - val_loss: 1.0469 - val_acc: 0.6637
# Epoch 177/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0763 - acc: 0.6580 - val_loss: 1.0396 - val_acc: 0.6620
# Epoch 178/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0686 - acc: 0.6577 - val_loss: 1.0352 - val_acc: 0.6589
# Epoch 179/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0586 - acc: 0.6560 - val_loss: 1.0307 - val_acc: 0.6562
# Epoch 180/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 1.0438 - acc: 0.6533 - val_loss: 1.0124 - val_acc: 0.6480
# Epoch 181/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9973 - acc: 0.6396 - val_loss: 0.9894 - val_acc: 0.6384
# Epoch 182/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9866 - acc: 0.6446 - val_loss: 0.9740 - val_acc: 0.6437
# Epoch 183/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.9753 - acc: 0.6463 - val_loss: 0.9651 - val_acc: 0.6447
# Epoch 184/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9670 - acc: 0.6483 - val_loss: 0.9598 - val_acc: 0.6474
# Epoch 185/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9641 - acc: 0.6510 - val_loss: 0.9543 - val_acc: 0.6480
# Epoch 186/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9616 - acc: 0.6506 - val_loss: 0.9501 - val_acc: 0.6505
# Epoch 187/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9586 - acc: 0.6526 - val_loss: 0.9466 - val_acc: 0.6511
# Epoch 188/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9553 - acc: 0.6535 - val_loss: 0.9446 - val_acc: 0.6522
# Epoch 189/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9521 - acc: 0.6567 - val_loss: 0.9448 - val_acc: 0.6535
# Epoch 190/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9507 - acc: 0.6568 - val_loss: 0.9404 - val_acc: 0.6553
# Epoch 191/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9475 - acc: 0.6584 - val_loss: 0.9379 - val_acc: 0.6558
# Epoch 192/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9463 - acc: 0.6600 - val_loss: 0.9370 - val_acc: 0.6582
# Epoch 193/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9474 - acc: 0.6584 - val_loss: 0.9358 - val_acc: 0.6600
# Epoch 194/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9425 - acc: 0.6598 - val_loss: 0.9345 - val_acc: 0.6612
# Epoch 195/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9424 - acc: 0.6608 - val_loss: 0.9326 - val_acc: 0.6618
# Epoch 196/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9415 - acc: 0.6629 - val_loss: 0.9326 - val_acc: 0.6614
# Epoch 197/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9390 - acc: 0.6630 - val_loss: 0.9316 - val_acc: 0.6621
# Epoch 198/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9370 - acc: 0.6630 - val_loss: 0.9283 - val_acc: 0.6640
# Epoch 199/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9381 - acc: 0.6641 - val_loss: 0.9276 - val_acc: 0.6640
# Epoch 200/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9334 - acc: 0.6639 - val_loss: 0.9242 - val_acc: 0.6647
# Epoch 201/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9321 - acc: 0.6645 - val_loss: 0.9229 - val_acc: 0.6668
# Epoch 202/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9302 - acc: 0.6695 - val_loss: 0.9222 - val_acc: 0.6676
# Epoch 203/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9292 - acc: 0.6672 - val_loss: 0.9194 - val_acc: 0.6688
# Epoch 204/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9286 - acc: 0.6677 - val_loss: 0.9210 - val_acc: 0.6682
# Epoch 205/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9268 - acc: 0.6673 - val_loss: 0.9189 - val_acc: 0.6698
# Epoch 206/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9265 - acc: 0.6702 - val_loss: 0.9166 - val_acc: 0.6695
# Epoch 207/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9239 - acc: 0.6693 - val_loss: 0.9157 - val_acc: 0.6699
# Epoch 208/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9208 - acc: 0.6710 - val_loss: 0.9133 - val_acc: 0.6707
# Epoch 209/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9218 - acc: 0.6713 - val_loss: 0.9146 - val_acc: 0.6708
# Epoch 210/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9216 - acc: 0.6722 - val_loss: 0.9112 - val_acc: 0.6716
# Epoch 211/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9203 - acc: 0.6715 - val_loss: 0.9093 - val_acc: 0.6730
# Epoch 212/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9167 - acc: 0.6729 - val_loss: 0.9072 - val_acc: 0.6732
# Epoch 213/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9159 - acc: 0.6715 - val_loss: 0.9081 - val_acc: 0.6724
# Epoch 214/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9155 - acc: 0.6718 - val_loss: 0.9058 - val_acc: 0.6737
# Epoch 215/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9160 - acc: 0.6739 - val_loss: 0.9043 - val_acc: 0.6747
# Epoch 216/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9129 - acc: 0.6733 - val_loss: 0.9031 - val_acc: 0.6741
# Epoch 217/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.9106 - acc: 0.6716 - val_loss: 0.9024 - val_acc: 0.6744
# Epoch 218/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9135 - acc: 0.6740 - val_loss: 0.9009 - val_acc: 0.6750
# Epoch 219/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.9070 - acc: 0.6774 - val_loss: 0.8987 - val_acc: 0.6754
# Epoch 220/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9097 - acc: 0.6735 - val_loss: 0.8968 - val_acc: 0.6748
# Epoch 221/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9060 - acc: 0.6745 - val_loss: 0.8973 - val_acc: 0.6754
# Epoch 222/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.9051 - acc: 0.6731 - val_loss: 0.8976 - val_acc: 0.6749
# Epoch 223/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9034 - acc: 0.6744 - val_loss: 0.8956 - val_acc: 0.6755
# Epoch 224/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9035 - acc: 0.6750 - val_loss: 0.8968 - val_acc: 0.6765
# Epoch 225/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.9010 - acc: 0.6765 - val_loss: 0.8906 - val_acc: 0.6774
# Epoch 226/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8991 - acc: 0.6785 - val_loss: 0.8897 - val_acc: 0.6773
# Epoch 227/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8989 - acc: 0.6763 - val_loss: 0.8903 - val_acc: 0.6761
# Epoch 228/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8997 - acc: 0.6765 - val_loss: 0.8882 - val_acc: 0.6768
# Epoch 229/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.8967 - acc: 0.6766 - val_loss: 0.8855 - val_acc: 0.6775
# Epoch 230/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8957 - acc: 0.6773 - val_loss: 0.8854 - val_acc: 0.6776
# Epoch 231/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8958 - acc: 0.6771 - val_loss: 0.8833 - val_acc: 0.6778
# Epoch 232/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8933 - acc: 0.6783 - val_loss: 0.8829 - val_acc: 0.6786
# Epoch 233/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8931 - acc: 0.6781 - val_loss: 0.8847 - val_acc: 0.6777
# Epoch 234/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8913 - acc: 0.6776 - val_loss: 0.8836 - val_acc: 0.6778
# Epoch 235/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8923 - acc: 0.6770 - val_loss: 0.8834 - val_acc: 0.6791
# Epoch 236/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8898 - acc: 0.6778 - val_loss: 0.8829 - val_acc: 0.6797
# Epoch 237/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8904 - acc: 0.6792 - val_loss: 0.8794 - val_acc: 0.6792
# Epoch 238/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8872 - acc: 0.6782 - val_loss: 0.8787 - val_acc: 0.6803
# Epoch 239/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8862 - acc: 0.6786 - val_loss: 0.8773 - val_acc: 0.6796
# Epoch 240/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8846 - acc: 0.6801 - val_loss: 0.8773 - val_acc: 0.6798
# Epoch 241/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.8853 - acc: 0.6798 - val_loss: 0.8752 - val_acc: 0.6805
# Epoch 242/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.8845 - acc: 0.6800 - val_loss: 0.8746 - val_acc: 0.6800
# Epoch 243/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8810 - acc: 0.6799 - val_loss: 0.8730 - val_acc: 0.6804
# Epoch 244/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8825 - acc: 0.6807 - val_loss: 0.8726 - val_acc: 0.6809
# Epoch 245/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8790 - acc: 0.6804 - val_loss: 0.8703 - val_acc: 0.6826
# Epoch 246/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8807 - acc: 0.6801 - val_loss: 0.8685 - val_acc: 0.6813
# Epoch 247/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8781 - acc: 0.6793 - val_loss: 0.8687 - val_acc: 0.6825
# Epoch 248/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8798 - acc: 0.6824 - val_loss: 0.8691 - val_acc: 0.6819
# Epoch 249/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8769 - acc: 0.6807 - val_loss: 0.8658 - val_acc: 0.6826
# Epoch 250/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8766 - acc: 0.6805 - val_loss: 0.8656 - val_acc: 0.6821
# Epoch 251/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8736 - acc: 0.6796 - val_loss: 0.8652 - val_acc: 0.6823
# Epoch 252/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.8739 - acc: 0.6830 - val_loss: 0.8639 - val_acc: 0.6814
# Epoch 253/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.8748 - acc: 0.6802 - val_loss: 0.8608 - val_acc: 0.6823
# Epoch 254/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 0.8720 - acc: 0.6828 - val_loss: 0.8632 - val_acc: 0.6826
# Epoch 255/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 0.8719 - acc: 0.6826 - val_loss: 0.8595 - val_acc: 0.6834
# Epoch 256/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 0.8691 - acc: 0.6829 - val_loss: 0.8582 - val_acc: 0.6822
# Epoch 257/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 0.8677 - acc: 0.6819 - val_loss: 0.8599 - val_acc: 0.6833
# Epoch 258/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8665 - acc: 0.6834 - val_loss: 0.8582 - val_acc: 0.6839
# Epoch 259/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8666 - acc: 0.6811 - val_loss: 0.8561 - val_acc: 0.6840
# Epoch 260/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8636 - acc: 0.6838 - val_loss: 0.8552 - val_acc: 0.6847
# Epoch 261/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8629 - acc: 0.6829 - val_loss: 0.8543 - val_acc: 0.6836
# Epoch 262/1200
# 28/28 [==============================] - 1s 34ms/step - loss: 0.8631 - acc: 0.6820 - val_loss: 0.8553 - val_acc: 0.6850
# Epoch 263/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8606 - acc: 0.6829 - val_loss: 0.8531 - val_acc: 0.6835
# Epoch 264/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8638 - acc: 0.6833 - val_loss: 0.8540 - val_acc: 0.6849
# Epoch 265/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8616 - acc: 0.6859 - val_loss: 0.8512 - val_acc: 0.6846
# Epoch 266/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8597 - acc: 0.6827 - val_loss: 0.8506 - val_acc: 0.6849
# Epoch 267/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8592 - acc: 0.6841 - val_loss: 0.8488 - val_acc: 0.6845
# Epoch 268/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8584 - acc: 0.6835 - val_loss: 0.8478 - val_acc: 0.6848
# Epoch 269/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8578 - acc: 0.6842 - val_loss: 0.8492 - val_acc: 0.6845
# Epoch 270/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8563 - acc: 0.6851 - val_loss: 0.8463 - val_acc: 0.6863
# Epoch 271/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8543 - acc: 0.6859 - val_loss: 0.8473 - val_acc: 0.6858
# Epoch 272/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8559 - acc: 0.6846 - val_loss: 0.8464 - val_acc: 0.6852
# Epoch 273/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8533 - acc: 0.6845 - val_loss: 0.8460 - val_acc: 0.6866
# Epoch 274/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8545 - acc: 0.6831 - val_loss: 0.8425 - val_acc: 0.6860
# Epoch 275/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8518 - acc: 0.6857 - val_loss: 0.8429 - val_acc: 0.6850
# Epoch 276/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8501 - acc: 0.6850 - val_loss: 0.8393 - val_acc: 0.6860
# Epoch 277/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8478 - acc: 0.6842 - val_loss: 0.8410 - val_acc: 0.6847
# Epoch 278/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 0.8498 - acc: 0.6865 - val_loss: 0.8394 - val_acc: 0.6866
# Epoch 279/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8479 - acc: 0.6862 - val_loss: 0.8398 - val_acc: 0.6862
# Epoch 280/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8476 - acc: 0.6866 - val_loss: 0.8371 - val_acc: 0.6866
# Epoch 281/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8459 - acc: 0.6870 - val_loss: 0.8398 - val_acc: 0.6868
# Epoch 282/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8465 - acc: 0.6845 - val_loss: 0.8360 - val_acc: 0.6876
# Epoch 283/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8418 - acc: 0.6874 - val_loss: 0.8373 - val_acc: 0.6865
# Epoch 284/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8442 - acc: 0.6865 - val_loss: 0.8355 - val_acc: 0.6869
# Epoch 285/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8444 - acc: 0.6872 - val_loss: 0.8346 - val_acc: 0.6880
# Epoch 286/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8406 - acc: 0.6867 - val_loss: 0.8354 - val_acc: 0.6877
# Epoch 287/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8417 - acc: 0.6856 - val_loss: 0.8321 - val_acc: 0.6880
# Epoch 288/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8409 - acc: 0.6860 - val_loss: 0.8331 - val_acc: 0.6876
# Epoch 289/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8372 - acc: 0.6890 - val_loss: 0.8297 - val_acc: 0.6881
# Epoch 290/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8369 - acc: 0.6868 - val_loss: 0.8279 - val_acc: 0.6887
# Epoch 291/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8368 - acc: 0.6868 - val_loss: 0.8288 - val_acc: 0.6885
# Epoch 292/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8369 - acc: 0.6873 - val_loss: 0.8274 - val_acc: 0.6885
# Epoch 293/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8361 - acc: 0.6871 - val_loss: 0.8267 - val_acc: 0.6894
# Epoch 294/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8342 - acc: 0.6875 - val_loss: 0.8254 - val_acc: 0.6897
# Epoch 295/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8324 - acc: 0.6859 - val_loss: 0.8267 - val_acc: 0.6894
# Epoch 296/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8348 - acc: 0.6874 - val_loss: 0.8241 - val_acc: 0.6894
# Epoch 297/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8310 - acc: 0.6888 - val_loss: 0.8256 - val_acc: 0.6903
# Epoch 298/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 0.8320 - acc: 0.6875 - val_loss: 0.8235 - val_acc: 0.6893
# Epoch 299/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8306 - acc: 0.6893 - val_loss: 0.8219 - val_acc: 0.6900
# Epoch 300/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8267 - acc: 0.6885 - val_loss: 0.8225 - val_acc: 0.6909
# Epoch 301/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8279 - acc: 0.6864 - val_loss: 0.8232 - val_acc: 0.6904
# Epoch 302/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8282 - acc: 0.6902 - val_loss: 0.8218 - val_acc: 0.6907
# Epoch 303/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8255 - acc: 0.6904 - val_loss: 0.8205 - val_acc: 0.6910
# Epoch 304/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8264 - acc: 0.6909 - val_loss: 0.8201 - val_acc: 0.6908
# Epoch 305/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8249 - acc: 0.6882 - val_loss: 0.8209 - val_acc: 0.6914
# Epoch 306/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8259 - acc: 0.6867 - val_loss: 0.8190 - val_acc: 0.6910
# Epoch 307/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8231 - acc: 0.6875 - val_loss: 0.8182 - val_acc: 0.6913
# Epoch 308/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8238 - acc: 0.6901 - val_loss: 0.8197 - val_acc: 0.6915
# Epoch 309/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 0.8215 - acc: 0.6901 - val_loss: 0.8167 - val_acc: 0.6921
# Epoch 310/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 0.8217 - acc: 0.6899 - val_loss: 0.8175 - val_acc: 0.6923
# Epoch 311/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 0.8187 - acc: 0.6891 - val_loss: 0.8158 - val_acc: 0.6921
# Epoch 312/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8215 - acc: 0.6894 - val_loss: 0.8161 - val_acc: 0.6919
# Epoch 313/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8188 - acc: 0.6906 - val_loss: 0.8150 - val_acc: 0.6928
# Epoch 314/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8177 - acc: 0.6898 - val_loss: 0.8145 - val_acc: 0.6937
# Epoch 315/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8192 - acc: 0.6912 - val_loss: 0.8140 - val_acc: 0.6930
# Epoch 316/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8168 - acc: 0.6917 - val_loss: 0.8146 - val_acc: 0.6931
# Epoch 317/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8167 - acc: 0.6905 - val_loss: 0.8130 - val_acc: 0.6926
# Epoch 318/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8143 - acc: 0.6903 - val_loss: 0.8114 - val_acc: 0.6932
# Epoch 319/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8152 - acc: 0.6919 - val_loss: 0.8127 - val_acc: 0.6939
# Epoch 320/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8135 - acc: 0.6899 - val_loss: 0.8108 - val_acc: 0.6949
# Epoch 321/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.8119 - acc: 0.6905 - val_loss: 0.8111 - val_acc: 0.6941
# Epoch 322/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8100 - acc: 0.6929 - val_loss: 0.8116 - val_acc: 0.6943
# Epoch 323/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8110 - acc: 0.6909 - val_loss: 0.8092 - val_acc: 0.6953
# Epoch 324/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8112 - acc: 0.6937 - val_loss: 0.8088 - val_acc: 0.6943
# Epoch 325/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8105 - acc: 0.6917 - val_loss: 0.8081 - val_acc: 0.6958
# Epoch 326/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8091 - acc: 0.6912 - val_loss: 0.8078 - val_acc: 0.6945
# Epoch 327/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8060 - acc: 0.6922 - val_loss: 0.8071 - val_acc: 0.6947
# Epoch 328/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8075 - acc: 0.6907 - val_loss: 0.8060 - val_acc: 0.6949
# Epoch 329/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8086 - acc: 0.6924 - val_loss: 0.8053 - val_acc: 0.6958
# Epoch 330/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8047 - acc: 0.6919 - val_loss: 0.8039 - val_acc: 0.6944
# Epoch 331/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8063 - acc: 0.6927 - val_loss: 0.8032 - val_acc: 0.6950
# Epoch 332/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8061 - acc: 0.6912 - val_loss: 0.8039 - val_acc: 0.6949
# Epoch 333/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8065 - acc: 0.6923 - val_loss: 0.8038 - val_acc: 0.6949
# Epoch 334/1200
# 28/28 [==============================] - 1s 39ms/step - loss: 0.8051 - acc: 0.6922 - val_loss: 0.8044 - val_acc: 0.6956
# Epoch 335/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8040 - acc: 0.6925 - val_loss: 0.8025 - val_acc: 0.6957
# Epoch 336/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8035 - acc: 0.6926 - val_loss: 0.8021 - val_acc: 0.6964
# Epoch 337/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8010 - acc: 0.6937 - val_loss: 0.8008 - val_acc: 0.6952
# Epoch 338/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.8024 - acc: 0.6926 - val_loss: 0.8016 - val_acc: 0.6964
# Epoch 339/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7991 - acc: 0.6941 - val_loss: 0.8019 - val_acc: 0.6959
# Epoch 340/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8017 - acc: 0.6917 - val_loss: 0.8017 - val_acc: 0.6961
# Epoch 341/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7985 - acc: 0.6952 - val_loss: 0.7998 - val_acc: 0.6961
# Epoch 342/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.8011 - acc: 0.6926 - val_loss: 0.8004 - val_acc: 0.6954
# Epoch 343/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7975 - acc: 0.6922 - val_loss: 0.7991 - val_acc: 0.6962
# Epoch 344/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7976 - acc: 0.6940 - val_loss: 0.7976 - val_acc: 0.6967
# Epoch 345/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7977 - acc: 0.6934 - val_loss: 0.7978 - val_acc: 0.6973
# Epoch 346/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7971 - acc: 0.6941 - val_loss: 0.7984 - val_acc: 0.6964
# Epoch 347/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7959 - acc: 0.6942 - val_loss: 0.7966 - val_acc: 0.6972
# Epoch 348/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7951 - acc: 0.6935 - val_loss: 0.7947 - val_acc: 0.6974
# Epoch 349/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7929 - acc: 0.6966 - val_loss: 0.7962 - val_acc: 0.6973
# Epoch 350/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7933 - acc: 0.6948 - val_loss: 0.7971 - val_acc: 0.6972
# Epoch 351/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.7950 - acc: 0.6945 - val_loss: 0.7945 - val_acc: 0.6976
# Epoch 352/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.7905 - acc: 0.6938 - val_loss: 0.7962 - val_acc: 0.6972
# Epoch 353/1200
# ...
# Epoch 1084/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6097 - acc: 0.7294 - val_loss: 0.6966 - val_acc: 0.7232
# Epoch 1085/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6109 - acc: 0.7307 - val_loss: 0.6946 - val_acc: 0.7223
# Epoch 1086/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6086 - acc: 0.7298 - val_loss: 0.6955 - val_acc: 0.7217
# Epoch 1087/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6083 - acc: 0.7311 - val_loss: 0.6946 - val_acc: 0.7225
# Epoch 1088/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6083 - acc: 0.7287 - val_loss: 0.6946 - val_acc: 0.7218
# Epoch 1089/1200
# 28/28 [==============================] - 1s 31ms/step - loss: 0.6086 - acc: 0.7294 - val_loss: 0.6948 - val_acc: 0.7224
# Epoch 1090/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6086 - acc: 0.7310 - val_loss: 0.6945 - val_acc: 0.7225
# Epoch 1091/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6089 - acc: 0.7320 - val_loss: 0.6961 - val_acc: 0.7215
# Epoch 1092/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6080 - acc: 0.7302 - val_loss: 0.6944 - val_acc: 0.7222
# Epoch 1093/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6084 - acc: 0.7295 - val_loss: 0.6948 - val_acc: 0.7226
# Epoch 1094/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6076 - acc: 0.7305 - val_loss: 0.6951 - val_acc: 0.7218
# Epoch 1095/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6080 - acc: 0.7295 - val_loss: 0.6935 - val_acc: 0.7225
# Epoch 1096/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6088 - acc: 0.7301 - val_loss: 0.6947 - val_acc: 0.7223
# Epoch 1097/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6072 - acc: 0.7303 - val_loss: 0.6952 - val_acc: 0.7231
# Epoch 1098/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6066 - acc: 0.7311 - val_loss: 0.6941 - val_acc: 0.7227
# Epoch 1099/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6069 - acc: 0.7306 - val_loss: 0.6959 - val_acc: 0.7228
# Epoch 1100/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6069 - acc: 0.7301 - val_loss: 0.6951 - val_acc: 0.7231
# Epoch 1101/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6089 - acc: 0.7301 - val_loss: 0.6930 - val_acc: 0.7236
# Epoch 1102/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6067 - acc: 0.7297 - val_loss: 0.6954 - val_acc: 0.7224
# Epoch 1103/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6079 - acc: 0.7297 - val_loss: 0.6947 - val_acc: 0.7228
# Epoch 1104/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6083 - acc: 0.7318 - val_loss: 0.6948 - val_acc: 0.7233
# Epoch 1105/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6054 - acc: 0.7306 - val_loss: 0.6952 - val_acc: 0.7232
# Epoch 1106/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6077 - acc: 0.7300 - val_loss: 0.6953 - val_acc: 0.7235
# Epoch 1107/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6063 - acc: 0.7310 - val_loss: 0.6935 - val_acc: 0.7233
# Epoch 1108/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6051 - acc: 0.7306 - val_loss: 0.6944 - val_acc: 0.7235
# Epoch 1109/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6093 - acc: 0.7309 - val_loss: 0.6964 - val_acc: 0.7234
# Epoch 1110/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6062 - acc: 0.7310 - val_loss: 0.6955 - val_acc: 0.7236
# Epoch 1111/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6040 - acc: 0.7305 - val_loss: 0.6951 - val_acc: 0.7242
# Epoch 1112/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6043 - acc: 0.7296 - val_loss: 0.6955 - val_acc: 0.7225
# Epoch 1113/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6071 - acc: 0.7317 - val_loss: 0.6947 - val_acc: 0.7229
# Epoch 1114/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6056 - acc: 0.7317 - val_loss: 0.6941 - val_acc: 0.7227
# Epoch 1115/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6053 - acc: 0.7298 - val_loss: 0.6950 - val_acc: 0.7231
# Epoch 1116/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6047 - acc: 0.7303 - val_loss: 0.6940 - val_acc: 0.7228
# Epoch 1117/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6054 - acc: 0.7313 - val_loss: 0.6948 - val_acc: 0.7234
# Epoch 1118/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6071 - acc: 0.7316 - val_loss: 0.6930 - val_acc: 0.7233
# Epoch 1119/1200
# 28/28 [==============================] - 1s 27ms/step - loss: 0.6045 - acc: 0.7311 - val_loss: 0.6956 - val_acc: 0.7236
# Epoch 1120/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6058 - acc: 0.7311 - val_loss: 0.6948 - val_acc: 0.7233
# Epoch 1121/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6057 - acc: 0.7306 - val_loss: 0.6927 - val_acc: 0.7232
# Epoch 1122/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6048 - acc: 0.7317 - val_loss: 0.6944 - val_acc: 0.7229
# Epoch 1123/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6043 - acc: 0.7306 - val_loss: 0.6944 - val_acc: 0.7220
# Epoch 1124/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6062 - acc: 0.7310 - val_loss: 0.6957 - val_acc: 0.7235
# Epoch 1125/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6061 - acc: 0.7322 - val_loss: 0.6958 - val_acc: 0.7231
# Epoch 1126/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6049 - acc: 0.7309 - val_loss: 0.6940 - val_acc: 0.7235
# Epoch 1127/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6039 - acc: 0.7312 - val_loss: 0.6932 - val_acc: 0.7226
# Epoch 1128/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6043 - acc: 0.7313 - val_loss: 0.6957 - val_acc: 0.7232
# Epoch 1129/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6054 - acc: 0.7322 - val_loss: 0.6931 - val_acc: 0.7234
# Epoch 1130/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6034 - acc: 0.7311 - val_loss: 0.6952 - val_acc: 0.7235
# Epoch 1131/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6053 - acc: 0.7315 - val_loss: 0.6948 - val_acc: 0.7229
# Epoch 1132/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6067 - acc: 0.7309 - val_loss: 0.6933 - val_acc: 0.7233
# Epoch 1133/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6030 - acc: 0.7310 - val_loss: 0.6940 - val_acc: 0.7236
# Epoch 1134/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6064 - acc: 0.7315 - val_loss: 0.6950 - val_acc: 0.7232
# Epoch 1135/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6041 - acc: 0.7316 - val_loss: 0.6948 - val_acc: 0.7240
# Epoch 1136/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6048 - acc: 0.7308 - val_loss: 0.6939 - val_acc: 0.7221
# Epoch 1137/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.6018 - acc: 0.7312 - val_loss: 0.6942 - val_acc: 0.7223
# Epoch 1138/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6040 - acc: 0.7316 - val_loss: 0.6953 - val_acc: 0.7232
# Epoch 1139/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6034 - acc: 0.7321 - val_loss: 0.6934 - val_acc: 0.7236
# Epoch 1140/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6042 - acc: 0.7309 - val_loss: 0.6942 - val_acc: 0.7236
# Epoch 1141/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6037 - acc: 0.7320 - val_loss: 0.6944 - val_acc: 0.7227
# Epoch 1142/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6041 - acc: 0.7316 - val_loss: 0.6938 - val_acc: 0.7240
# Epoch 1143/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6032 - acc: 0.7312 - val_loss: 0.6931 - val_acc: 0.7235
# Epoch 1144/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 0.6027 - acc: 0.7326 - val_loss: 0.6940 - val_acc: 0.7226
# Epoch 1145/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6038 - acc: 0.7301 - val_loss: 0.6949 - val_acc: 0.7220
# Epoch 1146/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6042 - acc: 0.7298 - val_loss: 0.6940 - val_acc: 0.7223
# Epoch 1147/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6021 - acc: 0.7310 - val_loss: 0.6935 - val_acc: 0.7227
# Epoch 1148/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6037 - acc: 0.7313 - val_loss: 0.6931 - val_acc: 0.7225
# Epoch 1149/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6027 - acc: 0.7310 - val_loss: 0.6919 - val_acc: 0.7225
# Epoch 1150/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6014 - acc: 0.7308 - val_loss: 0.6936 - val_acc: 0.7222
# Epoch 1151/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6014 - acc: 0.7325 - val_loss: 0.6931 - val_acc: 0.7225
# Epoch 1152/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6031 - acc: 0.7320 - val_loss: 0.6944 - val_acc: 0.7231
# Epoch 1153/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6028 - acc: 0.7319 - val_loss: 0.6945 - val_acc: 0.7237
# Epoch 1154/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6022 - acc: 0.7319 - val_loss: 0.6929 - val_acc: 0.7230
# Epoch 1155/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6005 - acc: 0.7313 - val_loss: 0.6940 - val_acc: 0.7236
# Epoch 1156/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6005 - acc: 0.7324 - val_loss: 0.6942 - val_acc: 0.7236
# Epoch 1157/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6003 - acc: 0.7336 - val_loss: 0.6927 - val_acc: 0.7233
# Epoch 1158/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 0.6023 - acc: 0.7308 - val_loss: 0.6928 - val_acc: 0.7219
# Epoch 1159/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6016 - acc: 0.7302 - val_loss: 0.6929 - val_acc: 0.7231
# Epoch 1160/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6020 - acc: 0.7304 - val_loss: 0.6929 - val_acc: 0.7232
# Epoch 1161/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6022 - acc: 0.7320 - val_loss: 0.6927 - val_acc: 0.7231
# Epoch 1162/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6002 - acc: 0.7329 - val_loss: 0.6927 - val_acc: 0.7237
# Epoch 1163/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6023 - acc: 0.7325 - val_loss: 0.6932 - val_acc: 0.7241
# Epoch 1164/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6007 - acc: 0.7321 - val_loss: 0.6926 - val_acc: 0.7238
# Epoch 1165/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6009 - acc: 0.7325 - val_loss: 0.6929 - val_acc: 0.7230
# Epoch 1166/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5996 - acc: 0.7319 - val_loss: 0.6935 - val_acc: 0.7227
# Epoch 1167/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6017 - acc: 0.7334 - val_loss: 0.6930 - val_acc: 0.7230
# Epoch 1168/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5994 - acc: 0.7323 - val_loss: 0.6922 - val_acc: 0.7224
# Epoch 1169/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6013 - acc: 0.7333 - val_loss: 0.6932 - val_acc: 0.7237
# Epoch 1170/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5999 - acc: 0.7325 - val_loss: 0.6935 - val_acc: 0.7229
# Epoch 1171/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6001 - acc: 0.7320 - val_loss: 0.6933 - val_acc: 0.7224
# Epoch 1172/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6003 - acc: 0.7320 - val_loss: 0.6930 - val_acc: 0.7219
# Epoch 1173/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6005 - acc: 0.7330 - val_loss: 0.6927 - val_acc: 0.7228
# Epoch 1174/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6005 - acc: 0.7313 - val_loss: 0.6948 - val_acc: 0.7242
# Epoch 1175/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5995 - acc: 0.7314 - val_loss: 0.6921 - val_acc: 0.7228
# Epoch 1176/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5999 - acc: 0.7339 - val_loss: 0.6919 - val_acc: 0.7222
# Epoch 1177/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6006 - acc: 0.7325 - val_loss: 0.6923 - val_acc: 0.7231
# Epoch 1178/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6003 - acc: 0.7334 - val_loss: 0.6939 - val_acc: 0.7236
# Epoch 1179/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6008 - acc: 0.7333 - val_loss: 0.6932 - val_acc: 0.7235
# Epoch 1180/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 0.6025 - acc: 0.7323 - val_loss: 0.6907 - val_acc: 0.7229
# Epoch 1181/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5996 - acc: 0.7324 - val_loss: 0.6922 - val_acc: 0.7229
# Epoch 1182/1200
# 28/28 [==============================] - 1s 29ms/step - loss: 0.5987 - acc: 0.7332 - val_loss: 0.6936 - val_acc: 0.7217
# Epoch 1183/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6010 - acc: 0.7317 - val_loss: 0.6922 - val_acc: 0.7226
# Epoch 1184/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5996 - acc: 0.7325 - val_loss: 0.6915 - val_acc: 0.7226
# Epoch 1185/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6006 - acc: 0.7310 - val_loss: 0.6913 - val_acc: 0.7228
# Epoch 1186/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5983 - acc: 0.7324 - val_loss: 0.6919 - val_acc: 0.7230
# Epoch 1187/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.5985 - acc: 0.7307 - val_loss: 0.6924 - val_acc: 0.7228
# Epoch 1188/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5974 - acc: 0.7316 - val_loss: 0.6936 - val_acc: 0.7231
# Epoch 1189/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5999 - acc: 0.7336 - val_loss: 0.6927 - val_acc: 0.7223
# Epoch 1190/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5985 - acc: 0.7320 - val_loss: 0.6918 - val_acc: 0.7230
# Epoch 1191/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5998 - acc: 0.7322 - val_loss: 0.6931 - val_acc: 0.7238
# Epoch 1192/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5976 - acc: 0.7332 - val_loss: 0.6921 - val_acc: 0.7238
# Epoch 1193/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 0.5981 - acc: 0.7321 - val_loss: 0.6909 - val_acc: 0.7242
# Epoch 1194/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5971 - acc: 0.7331 - val_loss: 0.6928 - val_acc: 0.7242
# Epoch 1195/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.5986 - acc: 0.7330 - val_loss: 0.6928 - val_acc: 0.7225
# Epoch 1196/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.5978 - acc: 0.7327 - val_loss: 0.6914 - val_acc: 0.7236
# Epoch 1197/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5976 - acc: 0.7339 - val_loss: 0.6913 - val_acc: 0.7236
# Epoch 1198/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5986 - acc: 0.7306 - val_loss: 0.6926 - val_acc: 0.7232
# Epoch 1199/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5971 - acc: 0.7338 - val_loss: 0.6909 - val_acc: 0.7236
# Epoch 1200/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.5962 - acc: 0.7332 - val_loss: 0.6924 - val_acc: 0.7234

# %%
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %%
windowSize = 100
hour = 3
hour = min(hour, forecast_horizon)
print(f"Hours ahead = {hour}")
# Out:
# Hours ahead = 3

# %%
def getLabelArrays(hour, input_sequence_length=input_sequence_length):
    syncindex = input_sequence_length + hour - 1
    yTestPred = model.predict(test_dataset, verbose=0)
    ypredFull = yTestPred[:windowSize, hour-1, :,:]
    yactualFull = Ytest[syncindex:windowSize+syncindex:, :]
    mae1 = mean_absolute_error(ypredFull[:,:,0], yactualFull[:,:,0])
    mae2 = mean_absolute_error(ypredFull[:,:,1], yactualFull[:,:,1])

    return ypredFull, yactualFull, mae1, mae2


def plotComparison(airport_index, hour):
    ypredFull, yactualFull, _, _ = getLabelArrays(hour)
    fig, axs = plt.subplots(2, 1, sharex=True, num=airport_index)
    axs[0].plot(yactualFull[:, 0 + airport_index, 0], label="Actual Arrival Delay")
    axs[1].plot(yactualFull[:, airport_index, 1], label="Actual Departure Delay")
    axs[0].plot(ypredFull[:, 0 + airport_index, 0], label="Predicted Arrival Delay")
    axs[1].plot(ypredFull[:, airport_index, 1], label="Predicted Departure Delay")
    axs[0].legend()
    # axs[1].legend()
    axs[1].set_xlabel("Time (hours)")
    axs[0].set_ylabel("Arrival Delay (mins)")
    axs[1].set_ylabel("Departure Delay (mins)")
    plt.suptitle(f"Comparison for: {airports[airport_index]}. Forward: {hour}h, Backward: {hour}h")


def plotMAEOverTime(forecast_horizon=forecast_horizon):
    hours = list(range(1, forecast_horizon+1))
    maeList = []
    maeList2 = []
    for h in hours:
        _,_, mae1, mae2 = getLabelArrays(h)
        maeList.append(mae1)
        maeList2.append(mae2)
    plt.plot(hours, maeList)
    plt.plot(hours, maeList2)
    plt.xlabel("Look forward (hours)")
    plt.ylabel("MAE (minutes)")


plotMAEOverTime()
plt.show()

for airportidx in range(0, len(airports)):
    plotComparison(airportidx, hour)
# plt.show()

# %%
# P = generateKeplerAirports(airports, start, end, timeslotLength, [3,6,9,12], val_idx+14, yTestPred[:,0,:] , Ytest[14:])

# time_test = start + timedelta(timeslotLength*(val_idx+14))

# Q = generateKeplerFlightsMultiple(airports, time_test, end, timeslotLength, save_to_csv= True)

# %% [markdown]
# ## Add logbook to tensorboard

# %%
# !tensorboard dev upload --logdir ./logs \
#   --name "Tuning model 2" \
#   --description "Trying some stuff ans last run on TOP50"\
#   --one_shot

# %%
# a = np.asarray(Ytest[14:])
# np.savetxt("actualy.csv", a, delimiter=",")

print(start+timedelta(minutes=timeslotLength*(val_idx+45)))
# Out:
# 2018-06-14 13:00:00
