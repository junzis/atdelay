# %% [markdown]
# #### Inputs

# %%
import pandas as pd
import numpy as np
import os
import typing
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

from tensorflow.keras.regularizers import l2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import timeseries_dataset_from_array

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsoluteError, MeanSquaredError, MeanSquaredLogarithmicError

from extraction.extract import *
from extraction.extractionvalues import *
from extraction.extractadjacency import getAdjacencyMatrix, distance_weight_adjacency

from sklearn.metrics import mean_absolute_error, mean_squared_error
# %load_ext tensorboard
# %tensorboard --logdir logs/fit

# %% [markdown]
# ##### Data parameters

# %%
airports = [
    "EGLL",
    "LFPG",
    "EHAM",
    "EDDF",
    "LEMD",
    "LEBL",
    # "LTFM",
    "UUEE",
    "EDDM",
    "EGKK",
]

n_nodes = n_airports = len(airports)
start = datetime(2018, 3, 1)
end = datetime(2019, 1, 1)
timeslotLength = 60

# Run settings
batch_size = 64
epochs = 1200
patience = 100
input_sequence_length = 4
forecast_horizon = 10
multi_horizon = True

learning_rate = 0.0001
# learning_rate = 0.0005
# learning_rate = 0.005

# %% [markdown]
# ##### Load Data

# %%
dataDict = generateNNdataMultiple(
    airports, timeslotLength, GNNFormat=True, start=start, end=end, disableWeather=True
)
times = list(dataDict.values())[0]["T"]
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 23.48it/s]

# %% [markdown]
# ##### Process Data

# %%
columnsToDrop = [
    "weekend",
    "winter",
    "spring",
    "summer",
    "autumn",
    "night",
    "morning",
    "afternoon",
    "planes",
]
# print(dataDict["EGLL"]["X"].shape)
Xlist = []
Ylist = []
for airport in airports:
    # T x F
    X = dataDict[airport]["X"].drop(columnsToDrop, axis=1).to_numpy()
    Xlist.append(X)

    Y = dataDict[airport]["Y"].iloc[:,:].to_numpy()
    Ylist.append(Y)


Xlist = np.stack(Xlist)
Ylist = np.stack(Ylist)
# N x T x F
Xarray = np.swapaxes(Xlist, 0, 1)
Yarray = np.swapaxes(Ylist, 0, 1)

# Reshape to a flat array that goes arrival then departure delay
# Yarray = np.reshape(Yarray, newshape=[len(times), len(airports)*2], order="F")

# print(Yarray.shape)
# T x N x F

# Normalise over the features
Xmean, Xstd = X.mean(axis=0), X.std(axis=0)
X = (X - Xmean) / Xstd
print("X Mean Shape", Xmean.shape)
Ymean, Ystd = Y.mean(axis=0), Y.std(axis=0)
Y = (Y - Ymean) / Ystd
print("Y Mean Shape", Ymean.shape)

print("T x N x F: ", "Xarray =", Xarray.shape, "|", "Yarray =", Yarray.shape)
# Out:
# X Mean Shape (8,)
# Y Mean Shape (2,)
# T x N x F:  Xarray = (2928, 9, 8) | Yarray = (2928, 9, 2)

# %%
train_split, val_split = 0.6, 0.25

fullLength = len(times)
train_idx = int(train_split * fullLength)
val_idx = int((val_split + train_split) * fullLength)
print(train_idx, val_idx)

Xtrain, Xval, Xtest = Xarray[0:train_idx], Xarray[train_idx:val_idx], Xarray[val_idx::]
Ytrain, Yval, Ytest = Yarray[0:train_idx], Yarray[train_idx:val_idx], Yarray[val_idx::]
# Out:
# 1756 2488

# %% [markdown]
# ##### Create tensorflow dataset

# %%
def create_tf_dataset(
    data_array: np.ndarray,
    target_array,
    input_sequence_length: int,
    forecast_horizon: int,
    batch_size: int = 128,
    shuffle=True,
    multi_horizon=False,
):
    """Creates tensorflow dataset from numpy array.

    This function creates a dataset where each element is a tuple `(inputs, targets)`.
    `inputs` is a Tensor
    of shape `(batch_size, input_sequence_length, num_routes, 1)` containing
    the `input_sequence_length` past values of the timeseries for each node.
    `targets` is a Tensor of shape `(batch_size, forecast_horizon, num_routes)`
    containing the `forecast_horizon`
    future values of the timeseries for each node.

    Args:
        data_array: np.ndarray with shape `(num_time_steps, num_routes)`
        input_sequence_length: Length of the input sequence (in number of timesteps).
        forecast_horizon: If `multi_horizon=True`, the target will be the values of the timeseries for 1 to
            `forecast_horizon` timesteps ahead. If `multi_horizon=False`, the target will be the value of the
            timeseries `forecast_horizon` steps ahead (only one value).
        batch_size: Number of timeseries samples in each batch.
        shuffle: Whether to shuffle output samples, or instead draw them in chronological order.
        multi_horizon: See `forecast_horizon`.

    Returns:
        A tf.data.Dataset instance.
    """

    inputs = timeseries_dataset_from_array(
        data_array[:-forecast_horizon],
        None,
        sequence_length=input_sequence_length,
        shuffle=False,
        batch_size=batch_size,
    )

    dataset = inputs
    target_offset = (
        input_sequence_length
        if multi_horizon
        else input_sequence_length + forecast_horizon - 1
    )
    target_seq_length = forecast_horizon if multi_horizon else 1
    targets = timeseries_dataset_from_array(
        target_array[target_offset:],
        None,
        sequence_length=target_seq_length,
        shuffle=False,
        batch_size=batch_size,
    )

    dataset = tf.data.Dataset.zip((inputs, targets))
    if shuffle:
        dataset = dataset.shuffle(100)

    return dataset.prefetch(16).cache()


train_dataset = create_tf_dataset(
    Xtrain,
    Ytrain,
    input_sequence_length,
    forecast_horizon,
    batch_size=batch_size,
    shuffle=False,
    multi_horizon=multi_horizon,
)

val_dataset = create_tf_dataset(
    Xval,
    Yval,
    input_sequence_length,
    forecast_horizon,
    batch_size=batch_size,
    shuffle=False,
    multi_horizon=multi_horizon,
)
test_dataset = create_tf_dataset(
    Xtest,
    Ytest,
    input_sequence_length,
    forecast_horizon,
    batch_size=batch_size,
    shuffle=False,
    multi_horizon=multi_horizon,
)

print(train_dataset)
# Out:
# <CacheDataset shapes: ((None, None, 9, 8), (None, None, 9, 2)), types: (tf.float64, tf.float64)>

# %% [markdown]
# # Adjacency Matrix

# %%
class GraphInfo:
    def __init__(self, edges: typing.Tuple[list, list], num_nodes: int):
        self.edges = edges
        self.num_nodes = num_nodes


distance_adj = distance_weight_adjacency(
    airports, threshold=400
)  # getAdjacencyMatrix(airports)[10]
# flight_adj = np.mean(
#     getAdjacencyMatrix(airports, start, end, timeslotLength), axis=0)
flight_adj = np.array(
    [
        [
            0.0,
            0.06728142076502733,
            0.07493169398907065,
            0.11737249544626573,
            0.08731785063752331,
            0.08691939890710383,
            0.05976775956284153,
            0.09995446265938075,
            0.00034153005464480874,
        ],
        [
            0.09221311475409882,
            0.0,
            0.07809653916211337,
            0.08891165755919873,
            0.06819216757741367,
            0.07900728597449944,
            0.09375,
            0.11372950819672131,
            0.052424863387978145,
        ],
        [
            0.09153005464480875,
            0.11270491803278689,
            0.0,
            0.07729963570127565,
            0.08965163934426229,
            0.0782103825136618,
            0.05140027322404372,
            0.07627504553734095,
            0.06841985428051031,
        ],
        [
            0.08760245901639344,
            0.08822859744990921,
            0.07821038251366169,
            0.0,
            0.07320127504553768,
            0.05794626593806932,
            0.0469603825136612,
            0.09301001821493657,
            0.0006830601092896175,
        ],
        [
            0.0875455373406198,
            0.06830601092896188,
            0.09187158469945356,
            0.07308743169398944,
            0.0,
            0.0933060109289611,
            0.05225409836065574,
            0.0617030965391622,
            0.06545992714025516,
        ],
        [
            0.08691939890710383,
            0.08014571948998225,
            0.07946265938069258,
            0.08709016393442623,
            0.09323770491803217,
            0.0,
            0.04337431693989071,
            0.08504098360655737,
            0.10040983606557388,
        ],
        [
            0.039731329690346005,
            0.06193078324225894,
            0.05140027322404372,
            0.08299180327868852,
            0.05157103825136612,
            0.08572404371584699,
            0.0,
            0.08265027322404371,
            0.0,
        ],
        [
            0.100068306010929,
            0.11321721311475409,
            0.07877959927140268,
            0.0943761384335157,
            0.09170081967213115,
            0.08487021857923498,
            0.08333333333333333,
            0.0,
            0.05362021857923497,
        ],
        [
            0.0006830601092896175,
            0.05259562841530055,
            0.07081056466302399,
            0.0,
            0.06534608378870696,
            0.10029599271402556,
            0.0,
            0.05430327868852459,
            0.0,
        ],
    ]
)
adjacency_matrix = distance_adj * 0.4 + (1 - 0.4) * flight_adj
# adjacency_matrix = distance_adj
# adjacency_matrix = np.ones((10,10))/2
# print(adjacency_matrix.shape)
# print(adjacency_matrix)
node_indices, neighbor_indices = np.where(adjacency_matrix != 0)
graph = GraphInfo(
    edges=(node_indices.tolist(), neighbor_indices.tolist()),
    num_nodes=adjacency_matrix.shape[0],
)
# print(adjacency_matrix)
# # print(adjacency_matrix.shape)
# print(np.where(adjacency_matrix != 0))
# print(np.where(adjacency_matrix != 0).shape)

# %%
print(flight_adj.shape)
# Out:
# (9, 9)

# %%
plt.imshow(adjacency_matrix)
plt.xticks(range(len(airports)), airports, fontsize=12, rotation=-90)
plt.yticks(range(len(airports)), airports, fontsize=12, rotation=0)
plt.show()

# %% [markdown]
# ## Graph Convolution Layer

# %%
class GraphConv(layers.Layer):
    def __init__(
        self,
        in_feat,
        out_feat,
        graph_info: GraphInfo,
        aggregation_type="mean",
        combination_type="concat",
        activation: typing.Optional[str] = None,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.graph_info = graph_info

        self.aggregation_type = aggregation_type
        self.combination_type = combination_type
        self.weight = tf.Variable(
            initial_value=keras.initializers.glorot_uniform()(
                shape=(in_feat, out_feat), dtype="float32"
            ),
            trainable=True,
        )
        self.activation = layers.Activation(activation)

    def aggregate(self, neighbour_representations: tf.Tensor):
        aggregation_func = {
            "sum": tf.math.unsorted_segment_sum,
            "mean": tf.math.unsorted_segment_mean,
            "max": tf.math.unsorted_segment_max,
        }.get(self.aggregation_type)

        if aggregation_func:
            return aggregation_func(
                neighbour_representations,
                self.graph_info.edges[0],
                num_segments=self.graph_info.num_nodes,
            )

        raise ValueError(f"Invalid aggregation type: {self.aggregation_type}")

    def compute_nodes_representation(self, features: tf.Tensor):
        """Computes each node's representation.

        The nodes' representations are obtained by multiplying the features tensor with
        `self.weight`. Note that
        `self.weight` has shape `(in_feat, out_feat)`.

        Args:
            features: Tensor of shape `(num_nodes, batch_size, input_seq_len, in_feat)`

        Returns:
            A tensor of shape `(num_nodes, batch_size, input_seq_len, out_feat)`
        """
        return tf.matmul(features, self.weight)

    def compute_aggregated_messages(self, features: tf.Tensor):
        neighbour_representations = tf.gather(features, self.graph_info.edges[1])
        aggregated_messages = self.aggregate(neighbour_representations)
        return tf.matmul(aggregated_messages, self.weight)

    def update(self, nodes_representation: tf.Tensor, aggregated_messages: tf.Tensor):
        if self.combination_type == "concat":
            h = tf.concat([nodes_representation, aggregated_messages], axis=-1)
        elif self.combination_type == "add":
            h = nodes_representation + aggregated_messages
        else:
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        return self.activation(h)

    def call(self, features: tf.Tensor):
        """Forward pass.

        Args:
            features: tensor of shape `(num_nodes, batch_size, input_seq_len, in_feat)`

        Returns:
            A tensor of shape `(num_nodes, batch_size, input_seq_len, out_feat)`
        """
        nodes_representation = self.compute_nodes_representation(features)
        aggregated_messages = self.compute_aggregated_messages(features)
        return self.update(nodes_representation, aggregated_messages)

# %% [markdown]
# ## LSTM including graph convolution layer

# %%
class LSTMGC(layers.Layer):
    """Layer comprising a convolution layer followed by LSTM and dense layers."""

    def __init__(
        self,
        in_feat,
        out_feat,
        lstm_units: int,
        input_seq_len: int,
        # output_seq_len: int,
        graph_info: GraphInfo,
        graph_conv_params: typing.Optional[dict] = None,
        num_labels:int = 2,
        multi_horizon: int = True,
        forecast_horizon: int = forecast_horizon,
        **kwargs,
    ):

        if multi_horizon:
            self.forecast_horizon = forecast_horizon
        else:
            self.forecast_horizon = 1

        self.in_feat = in_feat
        self.out_feat = out_feat
        self.lstm_units = lstm_units
        self.input_seq_len = input_seq_len
        # self.output_seq_len = output_seq_len
        self.graph_info = graph_info
        self.graph_conv_params = graph_conv_params
        self.multi_horizon = multi_horizon
        self.num_labels = num_labels
        super().__init__(**kwargs)

        # graph conv layer
        if graph_conv_params is None:
            graph_conv_params = {
                "aggregation_type": "mean",
                "combination_type": "concat",
                "activation": None,
            }


        # Layer definitions
        self.graph_conv = GraphConv(in_feat, out_feat, graph_info, **graph_conv_params)
        self.graph_conv2 = GraphConv(in_feat, out_feat, graph_info, **graph_conv_params)
        l2_reg = 2.5e-4  # L2 regularization rate

        self.lstm1 = layers.LSTM(
            lstm_units,
            return_sequences=True,
            activation="tanh",
            dropout=0.2,
            kernel_regularizer=l2(l2_reg),
            activity_regularizer=l2(l2_reg),
            bias_regularizer=l2(l2_reg),
        )
        self.lstm2 = layers.LSTM(
            lstm_units,
            activation="tanh",
            dropout=0.2,
            kernel_regularizer=l2(l2_reg),
            activity_regularizer=l2(l2_reg),
            bias_regularizer=l2(l2_reg),
        )
        # self.dense = layers.Dense(output_seq_len)
        self.denseThick = layers.Dense(128)
        self.denseThick2 = layers.Dense(64)
        self.denseThick3 = layers.Dense(16)
        self.dense = layers.Dense(self.forecast_horizon * self.num_labels)

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "in_feat": self.in_feat,
                "out_feat": self.out_feat,
                "lstm_units": self.lstm_units,
                "input_seq_len": self.input_seq_len,
                "graph_info": self.graph_info,
                "graph_conv_params": self.graph_conv_params,
            }
        )
        return config

    def call(self, inputs):
        """Forward pass.

        Args:
            inputs: tf.Tensor of shape `(batch_size, input_seq_len, num_nodes, in_feat)`

        Returns:
            A tensor of shape `(batch_size, output_seq_len, num_nodes)`.
        """

        # convert shape to  (num_nodes, batch_size, input_seq_len, in_feat)
        inputs = tf.transpose(inputs, [2, 0, 1, 3])
        gcn_out = self.graph_conv(inputs)

        # print(f"The GCN output shape  = {gcn_out}")
        shape = tf.shape(gcn_out)
        num_nodes, batch_size, input_seq_len, out_feat = (
            shape[0],
            shape[1],
            shape[2],
            shape[3],
        )
        # LSTM takes only 3D tensors as input
        gcn_out = tf.reshape(gcn_out, (batch_size * num_nodes, input_seq_len, out_feat))
        # print(f"The input shape for the LSTM is {gcn_out}")
        lstmLayer1 = self.lstm1(
            gcn_out
        )  # lstm_out has shape: (batch_size * num_nodes, lstm_units)
        lstmLayer2 = self.lstm2(
            lstmLayer1
        ) 
        dense_1 = self.denseThick(lstmLayer2)
        dense_2 = self.denseThick2(dense_1)
        dense_3 = self.denseThick3(dense_2)

        dense_output = self.dense(dense_3)
        # dense_output has shape: (batch_size * num_nodes, multi_thing*2)

        output = tf.reshape(dense_output, (num_nodes, batch_size, self.forecast_horizon , self.num_labels))
        final = tf.transpose(output, [1, 2, 0, 3])
        return final
        # # returns Tensor of shape (batch_size, forecast_horizon, num_nodes, nlabels)

# %% [markdown]
# ## Training the model

# %%
in_feat = Xarray.shape[2]

out_feat = 15
lstm_units = 128
graph_conv_params = {
    "aggregation_type": "mean",
    "combination_type": "concat",
    "activation": None,
}

st_gcn = LSTMGC(
    in_feat = in_feat,
    out_feat = out_feat,
    lstm_units = lstm_units,
    input_seq_len = input_sequence_length,
    graph_info = graph,
    graph_conv_params = graph_conv_params,
    num_labels = 2,
    multi_horizon = multi_horizon,
    forecast_horizon = forecast_horizon ,
)


inputs = layers.Input(
    (input_sequence_length, graph.num_nodes, in_feat)
)# , batch_size=batch_size)
outputs = st_gcn(inputs)

model = keras.models.Model(inputs, outputs)

optimizer = Adam(learning_rate=learning_rate)
model.compile(
    optimizer=optimizer,
    loss=MeanAbsoluteError(reduction="auto", name="mean_absolute_error"),
    weighted_metrics=["acc"],
)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 4, 9, 8)]         0
#
#  lstmgc (LSTMGC)             (None, 10, 9, 2)          239380
#
# =================================================================
# Total params: 239,380
# Trainable params: 239,380
# Non-trainable params: 0
# _________________________________________________________________

# %%
log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)


history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    callbacks=[keras.callbacks.EarlyStopping(patience=patience), tensorboard_callback],
)
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Unable to serialize <__main__.GraphInfo object at 0x000002D682662790> to JSON. Unrecognized type <class '__main__.GraphInfo'>.
# Epoch 1/1200
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 28/28 [==============================] - 9s 57ms/step - loss: 8.0280 - acc: 0.5267 - val_loss: 6.8919 - val_acc: 0.5377
# Epoch 2/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 7.4888 - acc: 0.5418 - val_loss: 6.4254 - val_acc: 0.5407
# Epoch 3/1200
# 28/28 [==============================] - 1s 46ms/step - loss: 6.8864 - acc: 0.5617 - val_loss: 6.4534 - val_acc: 0.5771
# Epoch 4/1200
# 28/28 [==============================] - 2s 58ms/step - loss: 6.7545 - acc: 0.5807 - val_loss: 6.3072 - val_acc: 0.5777
# Epoch 5/1200
# 28/28 [==============================] - 1s 32ms/step - loss: 6.6595 - acc: 0.5817 - val_loss: 6.2530 - val_acc: 0.5781
# Epoch 6/1200
# 28/28 [==============================] - 1s 30ms/step - loss: 6.6018 - acc: 0.5823 - val_loss: 6.1998 - val_acc: 0.5793
# Epoch 7/1200
# 28/28 [==============================] - 2s 63ms/step - loss: 6.5537 - acc: 0.5822 - val_loss: 6.1538 - val_acc: 0.5811
# Epoch 8/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 6.5080 - acc: 0.5815 - val_loss: 6.1071 - val_acc: 0.5807
# Epoch 9/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 6.4618 - acc: 0.5804 - val_loss: 6.0641 - val_acc: 0.5788
# Epoch 10/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.4161 - acc: 0.5799 - val_loss: 6.0198 - val_acc: 0.5760
# Epoch 11/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 6.3690 - acc: 0.5796 - val_loss: 5.9771 - val_acc: 0.5735
# Epoch 12/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 6.3233 - acc: 0.5781 - val_loss: 5.9459 - val_acc: 0.5696
# Epoch 13/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 6.2847 - acc: 0.5769 - val_loss: 5.9246 - val_acc: 0.5642
# Epoch 14/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.2515 - acc: 0.5767 - val_loss: 5.9042 - val_acc: 0.5678
# Epoch 15/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 6.2271 - acc: 0.5782 - val_loss: 5.8787 - val_acc: 0.5680
# Epoch 16/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 6.2002 - acc: 0.5781 - val_loss: 5.8638 - val_acc: 0.5682
# Epoch 17/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 6.1879 - acc: 0.5778 - val_loss: 5.8455 - val_acc: 0.5686
# Epoch 18/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 6.1683 - acc: 0.5794 - val_loss: 5.8353 - val_acc: 0.5688
# Epoch 19/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 6.1564 - acc: 0.5793 - val_loss: 5.8197 - val_acc: 0.5692
# Epoch 20/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.1394 - acc: 0.5801 - val_loss: 5.8079 - val_acc: 0.5705
# Epoch 21/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.1316 - acc: 0.5814 - val_loss: 5.7929 - val_acc: 0.5717
# Epoch 22/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 6.1183 - acc: 0.5819 - val_loss: 5.7790 - val_acc: 0.5754
# Epoch 23/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.1043 - acc: 0.5835 - val_loss: 5.7735 - val_acc: 0.5820
# Epoch 24/1200
# 28/28 [==============================] - 1s 28ms/step - loss: 6.0954 - acc: 0.5861 - val_loss: 5.7566 - val_acc: 0.5835
# Epoch 25/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 6.0888 - acc: 0.5874 - val_loss: 5.7413 - val_acc: 0.5842
# Epoch 26/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 6.0739 - acc: 0.5896 - val_loss: 5.7336 - val_acc: 0.5862
# Epoch 27/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.0656 - acc: 0.5912 - val_loss: 5.7260 - val_acc: 0.5885
# Epoch 28/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.0543 - acc: 0.5938 - val_loss: 5.7130 - val_acc: 0.5907
# Epoch 29/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 6.0496 - acc: 0.5947 - val_loss: 5.7014 - val_acc: 0.5925
# Epoch 30/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.0348 - acc: 0.5971 - val_loss: 5.6920 - val_acc: 0.5946
# Epoch 31/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.0323 - acc: 0.5993 - val_loss: 5.6746 - val_acc: 0.5962
# Epoch 32/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.0151 - acc: 0.6013 - val_loss: 5.6635 - val_acc: 0.5987
# Epoch 33/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.0129 - acc: 0.6014 - val_loss: 5.6510 - val_acc: 0.6009
# Epoch 34/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 6.0001 - acc: 0.6032 - val_loss: 5.6453 - val_acc: 0.6030
# Epoch 35/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9931 - acc: 0.6047 - val_loss: 5.6408 - val_acc: 0.6069
# Epoch 36/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.9866 - acc: 0.6082 - val_loss: 5.6167 - val_acc: 0.6102
# Epoch 37/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.9753 - acc: 0.6101 - val_loss: 5.6063 - val_acc: 0.6140
# Epoch 38/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.9630 - acc: 0.6122 - val_loss: 5.6010 - val_acc: 0.6178
# Epoch 39/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9577 - acc: 0.6156 - val_loss: 5.5881 - val_acc: 0.6211
# Epoch 40/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9481 - acc: 0.6169 - val_loss: 5.5815 - val_acc: 0.6249
# Epoch 41/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9393 - acc: 0.6196 - val_loss: 5.5777 - val_acc: 0.6261
# Epoch 42/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9252 - acc: 0.6225 - val_loss: 5.5710 - val_acc: 0.6293
# Epoch 43/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9271 - acc: 0.6224 - val_loss: 5.5533 - val_acc: 0.6304
# Epoch 44/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9142 - acc: 0.6229 - val_loss: 5.5489 - val_acc: 0.6315
# Epoch 45/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.9053 - acc: 0.6267 - val_loss: 5.5363 - val_acc: 0.6328
# Epoch 46/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8968 - acc: 0.6243 - val_loss: 5.5289 - val_acc: 0.6338
# Epoch 47/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8879 - acc: 0.6279 - val_loss: 5.5279 - val_acc: 0.6353
# Epoch 48/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.8793 - acc: 0.6300 - val_loss: 5.5188 - val_acc: 0.6364
# Epoch 49/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.8714 - acc: 0.6284 - val_loss: 5.5143 - val_acc: 0.6367
# Epoch 50/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8537 - acc: 0.6309 - val_loss: 5.5119 - val_acc: 0.6374
# Epoch 51/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8602 - acc: 0.6297 - val_loss: 5.4965 - val_acc: 0.6386
# Epoch 52/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8479 - acc: 0.6295 - val_loss: 5.5028 - val_acc: 0.6409
# Epoch 53/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8436 - acc: 0.6306 - val_loss: 5.4958 - val_acc: 0.6415
# Epoch 54/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8331 - acc: 0.6313 - val_loss: 5.4899 - val_acc: 0.6431
# Epoch 55/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8293 - acc: 0.6340 - val_loss: 5.4846 - val_acc: 0.6443
# Epoch 56/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8170 - acc: 0.6357 - val_loss: 5.4894 - val_acc: 0.6448
# Epoch 57/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8118 - acc: 0.6362 - val_loss: 5.4753 - val_acc: 0.6457
# Epoch 58/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.8090 - acc: 0.6341 - val_loss: 5.4634 - val_acc: 0.6454
# Epoch 59/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.7997 - acc: 0.6338 - val_loss: 5.4682 - val_acc: 0.6451
# Epoch 60/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.7880 - acc: 0.6359 - val_loss: 5.4737 - val_acc: 0.6448
# Epoch 61/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.7871 - acc: 0.6365 - val_loss: 5.4557 - val_acc: 0.6471
# Epoch 62/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.7786 - acc: 0.6369 - val_loss: 5.4416 - val_acc: 0.6489
# Epoch 63/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.7676 - acc: 0.6386 - val_loss: 5.4376 - val_acc: 0.6492
# Epoch 64/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.7692 - acc: 0.6381 - val_loss: 5.4235 - val_acc: 0.6493
# Epoch 65/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.7509 - acc: 0.6388 - val_loss: 5.4162 - val_acc: 0.6488
# Epoch 66/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.7517 - acc: 0.6386 - val_loss: 5.4122 - val_acc: 0.6503
# Epoch 67/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.7433 - acc: 0.6403 - val_loss: 5.4100 - val_acc: 0.6507
# Epoch 68/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.7416 - acc: 0.6410 - val_loss: 5.4058 - val_acc: 0.6519
# Epoch 69/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.7237 - acc: 0.6412 - val_loss: 5.4009 - val_acc: 0.6531
# Epoch 70/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.7222 - acc: 0.6418 - val_loss: 5.3989 - val_acc: 0.6536
# Epoch 71/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.7103 - acc: 0.6432 - val_loss: 5.3894 - val_acc: 0.6547
# Epoch 72/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.7105 - acc: 0.6447 - val_loss: 5.3739 - val_acc: 0.6538
# Epoch 73/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.7035 - acc: 0.6444 - val_loss: 5.3737 - val_acc: 0.6542
# Epoch 74/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.6933 - acc: 0.6452 - val_loss: 5.3630 - val_acc: 0.6546
# Epoch 75/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.6896 - acc: 0.6450 - val_loss: 5.3773 - val_acc: 0.6546
# Epoch 76/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6790 - acc: 0.6482 - val_loss: 5.3578 - val_acc: 0.6558
# Epoch 77/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6719 - acc: 0.6484 - val_loss: 5.3617 - val_acc: 0.6561
# Epoch 78/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.6753 - acc: 0.6463 - val_loss: 5.3419 - val_acc: 0.6575
# Epoch 79/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6708 - acc: 0.6459 - val_loss: 5.3349 - val_acc: 0.6582
# Epoch 80/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.6703 - acc: 0.6497 - val_loss: 5.3311 - val_acc: 0.6576
# Epoch 81/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6635 - acc: 0.6454 - val_loss: 5.3177 - val_acc: 0.6595
# Epoch 82/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.6495 - acc: 0.6507 - val_loss: 5.3154 - val_acc: 0.6598
# Epoch 83/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6467 - acc: 0.6491 - val_loss: 5.3058 - val_acc: 0.6607
# Epoch 84/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.6423 - acc: 0.6507 - val_loss: 5.3004 - val_acc: 0.6626
# Epoch 85/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.6374 - acc: 0.6521 - val_loss: 5.2996 - val_acc: 0.6628
# Epoch 86/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6364 - acc: 0.6515 - val_loss: 5.2935 - val_acc: 0.6622
# Epoch 87/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6194 - acc: 0.6532 - val_loss: 5.2899 - val_acc: 0.6635
# Epoch 88/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6226 - acc: 0.6529 - val_loss: 5.2855 - val_acc: 0.6641
# Epoch 89/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6110 - acc: 0.6535 - val_loss: 5.2765 - val_acc: 0.6648
# Epoch 90/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.6061 - acc: 0.6550 - val_loss: 5.2784 - val_acc: 0.6651
# Epoch 91/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5999 - acc: 0.6560 - val_loss: 5.2773 - val_acc: 0.6654
# Epoch 92/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5998 - acc: 0.6537 - val_loss: 5.2735 - val_acc: 0.6665
# Epoch 93/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5912 - acc: 0.6546 - val_loss: 5.2623 - val_acc: 0.6678
# Epoch 94/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.5918 - acc: 0.6553 - val_loss: 5.2543 - val_acc: 0.6688
# Epoch 95/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.5767 - acc: 0.6562 - val_loss: 5.2604 - val_acc: 0.6685
# Epoch 96/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.5815 - acc: 0.6563 - val_loss: 5.2535 - val_acc: 0.6691
# Epoch 97/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.5771 - acc: 0.6573 - val_loss: 5.2408 - val_acc: 0.6692
# Epoch 98/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.5661 - acc: 0.6584 - val_loss: 5.2374 - val_acc: 0.6701
# Epoch 99/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5592 - acc: 0.6595 - val_loss: 5.2377 - val_acc: 0.6701
# Epoch 100/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5638 - acc: 0.6612 - val_loss: 5.2396 - val_acc: 0.6703
# Epoch 101/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5519 - acc: 0.6611 - val_loss: 5.2278 - val_acc: 0.6709
# Epoch 102/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5552 - acc: 0.6591 - val_loss: 5.2252 - val_acc: 0.6724
# Epoch 103/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5377 - acc: 0.6621 - val_loss: 5.2197 - val_acc: 0.6724
# Epoch 104/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5418 - acc: 0.6617 - val_loss: 5.2111 - val_acc: 0.6723
# Epoch 105/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5396 - acc: 0.6609 - val_loss: 5.2062 - val_acc: 0.6732
# Epoch 106/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.5366 - acc: 0.6634 - val_loss: 5.2041 - val_acc: 0.6736
# Epoch 107/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5344 - acc: 0.6618 - val_loss: 5.1941 - val_acc: 0.6746
# Epoch 108/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.5259 - acc: 0.6632 - val_loss: 5.1915 - val_acc: 0.6753
# Epoch 109/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5179 - acc: 0.6625 - val_loss: 5.1903 - val_acc: 0.6750
# Epoch 110/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5176 - acc: 0.6631 - val_loss: 5.1812 - val_acc: 0.6751
# Epoch 111/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5166 - acc: 0.6641 - val_loss: 5.1887 - val_acc: 0.6753
# Epoch 112/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.5192 - acc: 0.6630 - val_loss: 5.1776 - val_acc: 0.6761
# Epoch 113/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.5098 - acc: 0.6647 - val_loss: 5.1773 - val_acc: 0.6766
# Epoch 114/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.5006 - acc: 0.6639 - val_loss: 5.1726 - val_acc: 0.6763
# Epoch 115/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.5072 - acc: 0.6653 - val_loss: 5.1690 - val_acc: 0.6773
# Epoch 116/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4888 - acc: 0.6680 - val_loss: 5.1647 - val_acc: 0.6764
# Epoch 117/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4923 - acc: 0.6661 - val_loss: 5.1662 - val_acc: 0.6758
# Epoch 118/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.4915 - acc: 0.6655 - val_loss: 5.1550 - val_acc: 0.6756
# Epoch 119/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.4829 - acc: 0.6658 - val_loss: 5.1496 - val_acc: 0.6759
# Epoch 120/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4789 - acc: 0.6671 - val_loss: 5.1502 - val_acc: 0.6766
# Epoch 121/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4765 - acc: 0.6676 - val_loss: 5.1389 - val_acc: 0.6767
# Epoch 122/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4698 - acc: 0.6688 - val_loss: 5.1447 - val_acc: 0.6778
# Epoch 123/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4744 - acc: 0.6686 - val_loss: 5.1430 - val_acc: 0.6777
# Epoch 124/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4714 - acc: 0.6677 - val_loss: 5.1370 - val_acc: 0.6761
# Epoch 125/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4686 - acc: 0.6675 - val_loss: 5.1320 - val_acc: 0.6766
# Epoch 126/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4553 - acc: 0.6677 - val_loss: 5.1319 - val_acc: 0.6764
# Epoch 127/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4573 - acc: 0.6682 - val_loss: 5.1259 - val_acc: 0.6776
# Epoch 128/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4490 - acc: 0.6705 - val_loss: 5.1266 - val_acc: 0.6769
# Epoch 129/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.4466 - acc: 0.6689 - val_loss: 5.1224 - val_acc: 0.6771
# Epoch 130/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.4421 - acc: 0.6712 - val_loss: 5.1160 - val_acc: 0.6766
# Epoch 131/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.4468 - acc: 0.6717 - val_loss: 5.1186 - val_acc: 0.6770
# Epoch 132/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4404 - acc: 0.6703 - val_loss: 5.1135 - val_acc: 0.6761
# Epoch 133/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4297 - acc: 0.6694 - val_loss: 5.1084 - val_acc: 0.6764
# Epoch 134/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.4229 - acc: 0.6713 - val_loss: 5.1085 - val_acc: 0.6768
# Epoch 135/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4249 - acc: 0.6713 - val_loss: 5.1051 - val_acc: 0.6775
# Epoch 136/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4202 - acc: 0.6695 - val_loss: 5.1081 - val_acc: 0.6772
# Epoch 137/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4218 - acc: 0.6693 - val_loss: 5.1006 - val_acc: 0.6784
# Epoch 138/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4167 - acc: 0.6725 - val_loss: 5.0965 - val_acc: 0.6784
# Epoch 139/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4056 - acc: 0.6716 - val_loss: 5.0858 - val_acc: 0.6777
# Epoch 140/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 5.4072 - acc: 0.6714 - val_loss: 5.0848 - val_acc: 0.6787
# Epoch 141/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.4031 - acc: 0.6734 - val_loss: 5.0802 - val_acc: 0.6785
# Epoch 142/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.4035 - acc: 0.6729 - val_loss: 5.0824 - val_acc: 0.6791
# Epoch 143/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3878 - acc: 0.6722 - val_loss: 5.0813 - val_acc: 0.6795
# Epoch 144/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3931 - acc: 0.6731 - val_loss: 5.0737 - val_acc: 0.6787
# Epoch 145/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.4005 - acc: 0.6721 - val_loss: 5.0713 - val_acc: 0.6802
# Epoch 146/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3975 - acc: 0.6720 - val_loss: 5.0666 - val_acc: 0.6793
# Epoch 147/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3924 - acc: 0.6726 - val_loss: 5.0677 - val_acc: 0.6799
# Epoch 148/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3860 - acc: 0.6726 - val_loss: 5.0671 - val_acc: 0.6787
# Epoch 149/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3881 - acc: 0.6725 - val_loss: 5.0585 - val_acc: 0.6794
# Epoch 150/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3795 - acc: 0.6736 - val_loss: 5.0532 - val_acc: 0.6787
# Epoch 151/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3767 - acc: 0.6749 - val_loss: 5.0596 - val_acc: 0.6791
# Epoch 152/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.3693 - acc: 0.6749 - val_loss: 5.0609 - val_acc: 0.6792
# Epoch 153/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.3752 - acc: 0.6745 - val_loss: 5.0489 - val_acc: 0.6790
# Epoch 154/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.3698 - acc: 0.6751 - val_loss: 5.0465 - val_acc: 0.6790
# Epoch 155/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3613 - acc: 0.6740 - val_loss: 5.0430 - val_acc: 0.6802
# Epoch 156/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3515 - acc: 0.6754 - val_loss: 5.0374 - val_acc: 0.6799
# Epoch 157/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3596 - acc: 0.6763 - val_loss: 5.0345 - val_acc: 0.6804
# Epoch 158/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3494 - acc: 0.6771 - val_loss: 5.0367 - val_acc: 0.6798
# Epoch 159/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3480 - acc: 0.6759 - val_loss: 5.0418 - val_acc: 0.6795
# Epoch 160/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3484 - acc: 0.6768 - val_loss: 5.0340 - val_acc: 0.6802
# Epoch 161/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3427 - acc: 0.6756 - val_loss: 5.0279 - val_acc: 0.6796
# Epoch 162/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3366 - acc: 0.6763 - val_loss: 5.0323 - val_acc: 0.6794
# Epoch 163/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.3431 - acc: 0.6760 - val_loss: 5.0302 - val_acc: 0.6795
# Epoch 164/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.3402 - acc: 0.6771 - val_loss: 5.0278 - val_acc: 0.6790
# Epoch 165/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.3460 - acc: 0.6755 - val_loss: 5.0227 - val_acc: 0.6789
# Epoch 166/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.3253 - acc: 0.6764 - val_loss: 5.0213 - val_acc: 0.6784
# Epoch 167/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3296 - acc: 0.6769 - val_loss: 5.0156 - val_acc: 0.6785
# Epoch 168/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3239 - acc: 0.6782 - val_loss: 5.0196 - val_acc: 0.6786
# Epoch 169/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3274 - acc: 0.6771 - val_loss: 5.0048 - val_acc: 0.6793
# Epoch 170/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.3120 - acc: 0.6785 - val_loss: 5.0051 - val_acc: 0.6788
# Epoch 171/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3190 - acc: 0.6776 - val_loss: 5.0040 - val_acc: 0.6795
# Epoch 172/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.3166 - acc: 0.6779 - val_loss: 4.9934 - val_acc: 0.6794
# Epoch 173/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3094 - acc: 0.6769 - val_loss: 5.0001 - val_acc: 0.6799
# Epoch 174/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3127 - acc: 0.6782 - val_loss: 4.9991 - val_acc: 0.6787
# Epoch 175/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.3068 - acc: 0.6780 - val_loss: 4.9997 - val_acc: 0.6790
# Epoch 176/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.3139 - acc: 0.6777 - val_loss: 4.9912 - val_acc: 0.6796
# Epoch 177/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.2995 - acc: 0.6773 - val_loss: 4.9893 - val_acc: 0.6797
# Epoch 178/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.2948 - acc: 0.6803 - val_loss: 4.9897 - val_acc: 0.6799
# Epoch 179/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2999 - acc: 0.6776 - val_loss: 4.9899 - val_acc: 0.6798
# Epoch 180/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.3007 - acc: 0.6776 - val_loss: 4.9772 - val_acc: 0.6798
# Epoch 181/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2909 - acc: 0.6791 - val_loss: 4.9785 - val_acc: 0.6801
# Epoch 182/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2904 - acc: 0.6798 - val_loss: 4.9723 - val_acc: 0.6797
# Epoch 183/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2808 - acc: 0.6807 - val_loss: 4.9748 - val_acc: 0.6790
# Epoch 184/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2862 - acc: 0.6786 - val_loss: 4.9695 - val_acc: 0.6795
# Epoch 185/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2850 - acc: 0.6786 - val_loss: 4.9767 - val_acc: 0.6790
# Epoch 186/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2775 - acc: 0.6811 - val_loss: 4.9669 - val_acc: 0.6792
# Epoch 187/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2700 - acc: 0.6798 - val_loss: 4.9648 - val_acc: 0.6795
# Epoch 188/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.2742 - acc: 0.6795 - val_loss: 4.9614 - val_acc: 0.6794
# Epoch 189/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2695 - acc: 0.6816 - val_loss: 4.9652 - val_acc: 0.6792
# Epoch 190/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2700 - acc: 0.6799 - val_loss: 4.9644 - val_acc: 0.6794
# Epoch 191/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2714 - acc: 0.6794 - val_loss: 4.9536 - val_acc: 0.6783
# Epoch 192/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2651 - acc: 0.6800 - val_loss: 4.9575 - val_acc: 0.6795
# Epoch 193/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2527 - acc: 0.6818 - val_loss: 4.9516 - val_acc: 0.6796
# Epoch 194/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2461 - acc: 0.6815 - val_loss: 4.9466 - val_acc: 0.6791
# Epoch 195/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2509 - acc: 0.6817 - val_loss: 4.9464 - val_acc: 0.6797
# Epoch 196/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2462 - acc: 0.6824 - val_loss: 4.9487 - val_acc: 0.6798
# Epoch 197/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.2520 - acc: 0.6822 - val_loss: 4.9414 - val_acc: 0.6793
# Epoch 198/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.2443 - acc: 0.6797 - val_loss: 4.9434 - val_acc: 0.6796
# Epoch 199/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.2377 - acc: 0.6827 - val_loss: 4.9433 - val_acc: 0.6800
# Epoch 200/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.2410 - acc: 0.6832 - val_loss: 4.9349 - val_acc: 0.6797
# Epoch 201/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2324 - acc: 0.6838 - val_loss: 4.9308 - val_acc: 0.6800
# Epoch 202/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2271 - acc: 0.6812 - val_loss: 4.9301 - val_acc: 0.6810
# Epoch 203/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2238 - acc: 0.6833 - val_loss: 4.9309 - val_acc: 0.6811
# Epoch 204/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2308 - acc: 0.6826 - val_loss: 4.9371 - val_acc: 0.6802
# Epoch 205/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2352 - acc: 0.6812 - val_loss: 4.9339 - val_acc: 0.6805
# Epoch 206/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2317 - acc: 0.6818 - val_loss: 4.9256 - val_acc: 0.6816
# Epoch 207/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.2212 - acc: 0.6821 - val_loss: 4.9197 - val_acc: 0.6817
# Epoch 208/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2162 - acc: 0.6847 - val_loss: 4.9217 - val_acc: 0.6820
# Epoch 209/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2271 - acc: 0.6845 - val_loss: 4.9197 - val_acc: 0.6823
# Epoch 210/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.2223 - acc: 0.6828 - val_loss: 4.9230 - val_acc: 0.6818
# Epoch 211/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.2145 - acc: 0.6838 - val_loss: 4.9149 - val_acc: 0.6809
# Epoch 212/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.2128 - acc: 0.6837 - val_loss: 4.9108 - val_acc: 0.6815
# Epoch 213/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2169 - acc: 0.6816 - val_loss: 4.9200 - val_acc: 0.6809
# Epoch 214/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2077 - acc: 0.6830 - val_loss: 4.9105 - val_acc: 0.6805
# Epoch 215/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.2021 - acc: 0.6829 - val_loss: 4.9089 - val_acc: 0.6814
# Epoch 216/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1956 - acc: 0.6844 - val_loss: 4.9088 - val_acc: 0.6810
# Epoch 217/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.2003 - acc: 0.6822 - val_loss: 4.9103 - val_acc: 0.6809
# Epoch 218/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1999 - acc: 0.6846 - val_loss: 4.9059 - val_acc: 0.6816
# Epoch 219/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1953 - acc: 0.6850 - val_loss: 4.9002 - val_acc: 0.6819
# Epoch 220/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1908 - acc: 0.6847 - val_loss: 4.8988 - val_acc: 0.6810
# Epoch 221/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.1975 - acc: 0.6847 - val_loss: 4.8974 - val_acc: 0.6809
# Epoch 222/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1927 - acc: 0.6843 - val_loss: 4.8983 - val_acc: 0.6816
# Epoch 223/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1860 - acc: 0.6852 - val_loss: 4.9025 - val_acc: 0.6818
# Epoch 224/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1917 - acc: 0.6850 - val_loss: 4.8942 - val_acc: 0.6818
# Epoch 225/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1871 - acc: 0.6855 - val_loss: 4.8967 - val_acc: 0.6810
# Epoch 226/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1828 - acc: 0.6848 - val_loss: 4.8916 - val_acc: 0.6821
# Epoch 227/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1748 - acc: 0.6863 - val_loss: 4.8882 - val_acc: 0.6815
# Epoch 228/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1820 - acc: 0.6841 - val_loss: 4.8860 - val_acc: 0.6813
# Epoch 229/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1763 - acc: 0.6849 - val_loss: 4.8834 - val_acc: 0.6813
# Epoch 230/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1772 - acc: 0.6860 - val_loss: 4.8844 - val_acc: 0.6818
# Epoch 231/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1690 - acc: 0.6847 - val_loss: 4.8781 - val_acc: 0.6817
# Epoch 232/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1682 - acc: 0.6855 - val_loss: 4.8818 - val_acc: 0.6818
# Epoch 233/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1688 - acc: 0.6851 - val_loss: 4.8789 - val_acc: 0.6807
# Epoch 234/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1607 - acc: 0.6868 - val_loss: 4.8825 - val_acc: 0.6814
# Epoch 235/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1624 - acc: 0.6866 - val_loss: 4.8834 - val_acc: 0.6813
# Epoch 236/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1630 - acc: 0.6868 - val_loss: 4.8745 - val_acc: 0.6811
# Epoch 237/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1526 - acc: 0.6856 - val_loss: 4.8730 - val_acc: 0.6815
# Epoch 238/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1550 - acc: 0.6851 - val_loss: 4.8755 - val_acc: 0.6819
# Epoch 239/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1558 - acc: 0.6858 - val_loss: 4.8684 - val_acc: 0.6829
# Epoch 240/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1560 - acc: 0.6870 - val_loss: 4.8692 - val_acc: 0.6821
# Epoch 241/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1511 - acc: 0.6850 - val_loss: 4.8669 - val_acc: 0.6815
# Epoch 242/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1424 - acc: 0.6879 - val_loss: 4.8639 - val_acc: 0.6821
# Epoch 243/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1464 - acc: 0.6852 - val_loss: 4.8655 - val_acc: 0.6823
# Epoch 244/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1466 - acc: 0.6857 - val_loss: 4.8611 - val_acc: 0.6822
# Epoch 245/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1326 - acc: 0.6874 - val_loss: 4.8602 - val_acc: 0.6822
# Epoch 246/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1400 - acc: 0.6855 - val_loss: 4.8592 - val_acc: 0.6821
# Epoch 247/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1421 - acc: 0.6878 - val_loss: 4.8565 - val_acc: 0.6822
# Epoch 248/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.1428 - acc: 0.6860 - val_loss: 4.8564 - val_acc: 0.6814
# Epoch 249/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1312 - acc: 0.6861 - val_loss: 4.8604 - val_acc: 0.6815
# Epoch 250/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1321 - acc: 0.6880 - val_loss: 4.8506 - val_acc: 0.6821
# Epoch 251/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1213 - acc: 0.6877 - val_loss: 4.8504 - val_acc: 0.6818
# Epoch 252/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1154 - acc: 0.6901 - val_loss: 4.8521 - val_acc: 0.6824
# Epoch 253/1200
# 28/28 [==============================] - 0s 17ms/step - loss: 5.1288 - acc: 0.6881 - val_loss: 4.8439 - val_acc: 0.6817
# Epoch 254/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.1235 - acc: 0.6859 - val_loss: 4.8400 - val_acc: 0.6817
# Epoch 255/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1192 - acc: 0.6876 - val_loss: 4.8435 - val_acc: 0.6815
# Epoch 256/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 5.1182 - acc: 0.6880 - val_loss: 4.8452 - val_acc: 0.6822
# Epoch 257/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1200 - acc: 0.6878 - val_loss: 4.8389 - val_acc: 0.6821
# Epoch 258/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1150 - acc: 0.6861 - val_loss: 4.8353 - val_acc: 0.6825
# Epoch 259/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1125 - acc: 0.6888 - val_loss: 4.8416 - val_acc: 0.6822
# Epoch 260/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1222 - acc: 0.6870 - val_loss: 4.8315 - val_acc: 0.6819
# Epoch 261/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.1062 - acc: 0.6900 - val_loss: 4.8343 - val_acc: 0.6817
# Epoch 262/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1071 - acc: 0.6882 - val_loss: 4.8398 - val_acc: 0.6814
# Epoch 263/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1065 - acc: 0.6882 - val_loss: 4.8258 - val_acc: 0.6821
# Epoch 264/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.1122 - acc: 0.6881 - val_loss: 4.8304 - val_acc: 0.6825
# Epoch 265/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0995 - acc: 0.6881 - val_loss: 4.8239 - val_acc: 0.6825
# Epoch 266/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1026 - acc: 0.6909 - val_loss: 4.8242 - val_acc: 0.6829
# Epoch 267/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0970 - acc: 0.6876 - val_loss: 4.8222 - val_acc: 0.6830
# Epoch 268/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.0998 - acc: 0.6890 - val_loss: 4.8223 - val_acc: 0.6828
# Epoch 269/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.1004 - acc: 0.6895 - val_loss: 4.8202 - val_acc: 0.6829
# Epoch 270/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0925 - acc: 0.6885 - val_loss: 4.8167 - val_acc: 0.6831
# Epoch 271/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0911 - acc: 0.6889 - val_loss: 4.8139 - val_acc: 0.6830
# Epoch 272/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0886 - acc: 0.6905 - val_loss: 4.8164 - val_acc: 0.6826
# Epoch 273/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0890 - acc: 0.6901 - val_loss: 4.8167 - val_acc: 0.6825
# Epoch 274/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0900 - acc: 0.6887 - val_loss: 4.8115 - val_acc: 0.6832
# Epoch 275/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0876 - acc: 0.6900 - val_loss: 4.8121 - val_acc: 0.6825
# Epoch 276/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0815 - acc: 0.6890 - val_loss: 4.8117 - val_acc: 0.6835
# Epoch 277/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0806 - acc: 0.6903 - val_loss: 4.8177 - val_acc: 0.6835
# Epoch 278/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0733 - acc: 0.6884 - val_loss: 4.8050 - val_acc: 0.6827
# Epoch 279/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0778 - acc: 0.6895 - val_loss: 4.8087 - val_acc: 0.6830
# Epoch 280/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0728 - acc: 0.6881 - val_loss: 4.7978 - val_acc: 0.6827
# Epoch 281/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 5.0744 - acc: 0.6896 - val_loss: 4.7999 - val_acc: 0.6843
# Epoch 282/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0690 - acc: 0.6889 - val_loss: 4.8010 - val_acc: 0.6833
# Epoch 283/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0641 - acc: 0.6911 - val_loss: 4.8000 - val_acc: 0.6838
# Epoch 284/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0571 - acc: 0.6912 - val_loss: 4.7988 - val_acc: 0.6847
# Epoch 285/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 5.0683 - acc: 0.6888 - val_loss: 4.7960 - val_acc: 0.6834
# Epoch 286/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0626 - acc: 0.6905 - val_loss: 4.7951 - val_acc: 0.6837
# Epoch 287/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 5.0601 - acc: 0.6913 - val_loss: 4.7950 - val_acc: 0.6843
# Epoch 288/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 5.0591 - acc: 0.6916 - val_loss: 4.7932 - val_acc: 0.6842
# Epoch 289/1200
# 28/28 [==============================] - 1s 27ms/step - loss: 5.0581 - acc: 0.6889 - val_loss: 4.7940 - val_acc: 0.6841
# Epoch 290/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 5.0538 - acc: 0.6902 - val_loss: 4.7912 - val_acc: 0.6836
# Epoch 291/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0571 - acc: 0.6906 - val_loss: 4.7890 - val_acc: 0.6840
# Epoch 292/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0489 - acc: 0.6902 - val_loss: 4.7927 - val_acc: 0.6839
# Epoch 293/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0573 - acc: 0.6906 - val_loss: 4.7896 - val_acc: 0.6850
# Epoch 294/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0461 - acc: 0.6891 - val_loss: 4.7806 - val_acc: 0.6849
# Epoch 295/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0509 - acc: 0.6905 - val_loss: 4.7806 - val_acc: 0.6847
# Epoch 296/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0347 - acc: 0.6922 - val_loss: 4.7866 - val_acc: 0.6846
# Epoch 297/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0378 - acc: 0.6928 - val_loss: 4.7752 - val_acc: 0.6850
# Epoch 298/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 5.0406 - acc: 0.6922 - val_loss: 4.7781 - val_acc: 0.6852
# Epoch 299/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 5.0386 - acc: 0.6925 - val_loss: 4.7772 - val_acc: 0.6852
# Epoch 300/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 5.0422 - acc: 0.6914 - val_loss: 4.7804 - val_acc: 0.6846
# Epoch 301/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 5.0303 - acc: 0.6922 - val_loss: 4.7752 - val_acc: 0.6852
# Epoch 302/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 5.0303 - acc: 0.6921 - val_loss: 4.7811 - val_acc: 0.6857
# Epoch 303/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 5.0320 - acc: 0.6909 - val_loss: 4.7735 - val_acc: 0.6849
# Epoch 304/1200
# 28/28 [==============================] - 1s 30ms/step - loss: 5.0285 - acc: 0.6913 - val_loss: 4.7759 - val_acc: 0.6855
# Epoch 305/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0289 - acc: 0.6919 - val_loss: 4.7752 - val_acc: 0.6853
# Epoch 306/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0309 - acc: 0.6911 - val_loss: 4.7762 - val_acc: 0.6852
# Epoch 307/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0358 - acc: 0.6922 - val_loss: 4.7692 - val_acc: 0.6856
# Epoch 308/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0158 - acc: 0.6927 - val_loss: 4.7689 - val_acc: 0.6858
# Epoch 309/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0201 - acc: 0.6926 - val_loss: 4.7689 - val_acc: 0.6856
# Epoch 310/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0177 - acc: 0.6935 - val_loss: 4.7701 - val_acc: 0.6856
# Epoch 311/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0195 - acc: 0.6930 - val_loss: 4.7643 - val_acc: 0.6853
# Epoch 312/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 5.0170 - acc: 0.6925 - val_loss: 4.7670 - val_acc: 0.6845
# Epoch 313/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0179 - acc: 0.6932 - val_loss: 4.7657 - val_acc: 0.6851
# Epoch 314/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0110 - acc: 0.6935 - val_loss: 4.7623 - val_acc: 0.6857
# Epoch 315/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 5.0172 - acc: 0.6930 - val_loss: 4.7652 - val_acc: 0.6847
# Epoch 316/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0088 - acc: 0.6926 - val_loss: 4.7611 - val_acc: 0.6850
# Epoch 317/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0120 - acc: 0.6929 - val_loss: 4.7609 - val_acc: 0.6847
# Epoch 318/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9977 - acc: 0.6940 - val_loss: 4.7626 - val_acc: 0.6847
# Epoch 319/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0089 - acc: 0.6946 - val_loss: 4.7632 - val_acc: 0.6860
# Epoch 320/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 5.0047 - acc: 0.6928 - val_loss: 4.7531 - val_acc: 0.6854
# Epoch 321/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.9971 - acc: 0.6946 - val_loss: 4.7560 - val_acc: 0.6854
# Epoch 322/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9968 - acc: 0.6925 - val_loss: 4.7553 - val_acc: 0.6856
# Epoch 323/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.9982 - acc: 0.6936 - val_loss: 4.7573 - val_acc: 0.6867
# Epoch 324/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 4.9881 - acc: 0.6933 - val_loss: 4.7616 - val_acc: 0.6856
# Epoch 325/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 4.9973 - acc: 0.6937 - val_loss: 4.7551 - val_acc: 0.6863
# Epoch 326/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9958 - acc: 0.6958 - val_loss: 4.7555 - val_acc: 0.6867
# Epoch 327/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9888 - acc: 0.6959 - val_loss: 4.7551 - val_acc: 0.6861
# Epoch 328/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9892 - acc: 0.6951 - val_loss: 4.7488 - val_acc: 0.6859
# Epoch 329/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9882 - acc: 0.6949 - val_loss: 4.7548 - val_acc: 0.6860
# Epoch 330/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9856 - acc: 0.6932 - val_loss: 4.7497 - val_acc: 0.6858
# Epoch 331/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9797 - acc: 0.6950 - val_loss: 4.7481 - val_acc: 0.6859
# Epoch 332/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9738 - acc: 0.6941 - val_loss: 4.7486 - val_acc: 0.6851
# Epoch 333/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9791 - acc: 0.6951 - val_loss: 4.7477 - val_acc: 0.6860
# Epoch 334/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.9827 - acc: 0.6939 - val_loss: 4.7470 - val_acc: 0.6870
# Epoch 335/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9848 - acc: 0.6960 - val_loss: 4.7511 - val_acc: 0.6868
# Epoch 336/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.9782 - acc: 0.6952 - val_loss: 4.7414 - val_acc: 0.6861
# Epoch 337/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9776 - acc: 0.6952 - val_loss: 4.7422 - val_acc: 0.6867
# Epoch 338/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9631 - acc: 0.6955 - val_loss: 4.7420 - val_acc: 0.6866
# Epoch 339/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9774 - acc: 0.6949 - val_loss: 4.7355 - val_acc: 0.6872
# Epoch 340/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9659 - acc: 0.6951 - val_loss: 4.7402 - val_acc: 0.6877
# Epoch 341/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9740 - acc: 0.6959 - val_loss: 4.7351 - val_acc: 0.6880
# Epoch 342/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9633 - acc: 0.6965 - val_loss: 4.7326 - val_acc: 0.6882
# Epoch 343/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9671 - acc: 0.6950 - val_loss: 4.7334 - val_acc: 0.6869
# Epoch 344/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9704 - acc: 0.6950 - val_loss: 4.7351 - val_acc: 0.6878
# Epoch 345/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9685 - acc: 0.6963 - val_loss: 4.7278 - val_acc: 0.6870
# Epoch 346/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9597 - acc: 0.6961 - val_loss: 4.7295 - val_acc: 0.6874
# Epoch 347/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.9557 - acc: 0.6973 - val_loss: 4.7381 - val_acc: 0.6879
# Epoch 348/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.9562 - acc: 0.6978 - val_loss: 4.7314 - val_acc: 0.6869
# Epoch 349/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9590 - acc: 0.6975 - val_loss: 4.7265 - val_acc: 0.6901
# Epoch 350/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9549 - acc: 0.6963 - val_loss: 4.7279 - val_acc: 0.6886
# Epoch 351/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9598 - acc: 0.6965 - val_loss: 4.7289 - val_acc: 0.6878
# Epoch 352/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.9506 - acc: 0.6958 - val_loss: 4.7274 - val_acc: 0.6881
# Epoch 353/1200
# ...
# Epoch 1084/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.4063 - acc: 0.7350 - val_loss: 4.4565 - val_acc: 0.7141
# Epoch 1085/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.4060 - acc: 0.7334 - val_loss: 4.4601 - val_acc: 0.7172
# Epoch 1086/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4135 - acc: 0.7353 - val_loss: 4.4597 - val_acc: 0.7143
# Epoch 1087/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4090 - acc: 0.7334 - val_loss: 4.4609 - val_acc: 0.7139
# Epoch 1088/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4006 - acc: 0.7343 - val_loss: 4.4537 - val_acc: 0.7158
# Epoch 1089/1200
# 28/28 [==============================] - 1s 31ms/step - loss: 4.3993 - acc: 0.7349 - val_loss: 4.4603 - val_acc: 0.7141
# Epoch 1090/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.4116 - acc: 0.7332 - val_loss: 4.4548 - val_acc: 0.7144
# Epoch 1091/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3989 - acc: 0.7346 - val_loss: 4.4606 - val_acc: 0.7151
# Epoch 1092/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4050 - acc: 0.7348 - val_loss: 4.4563 - val_acc: 0.7144
# Epoch 1093/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4056 - acc: 0.7346 - val_loss: 4.4570 - val_acc: 0.7156
# Epoch 1094/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4044 - acc: 0.7335 - val_loss: 4.4552 - val_acc: 0.7150
# Epoch 1095/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4004 - acc: 0.7351 - val_loss: 4.4562 - val_acc: 0.7153
# Epoch 1096/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.4030 - acc: 0.7346 - val_loss: 4.4583 - val_acc: 0.7140
# Epoch 1097/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3947 - acc: 0.7356 - val_loss: 4.4573 - val_acc: 0.7158
# Epoch 1098/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3960 - acc: 0.7349 - val_loss: 4.4611 - val_acc: 0.7160
# Epoch 1099/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3966 - acc: 0.7357 - val_loss: 4.4587 - val_acc: 0.7147
# Epoch 1100/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 4.4010 - acc: 0.7353 - val_loss: 4.4605 - val_acc: 0.7153
# Epoch 1101/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3920 - acc: 0.7364 - val_loss: 4.4574 - val_acc: 0.7149
# Epoch 1102/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.4023 - acc: 0.7352 - val_loss: 4.4595 - val_acc: 0.7151
# Epoch 1103/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3953 - acc: 0.7348 - val_loss: 4.4632 - val_acc: 0.7152
# Epoch 1104/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.4012 - acc: 0.7364 - val_loss: 4.4614 - val_acc: 0.7153
# Epoch 1105/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3924 - acc: 0.7357 - val_loss: 4.4572 - val_acc: 0.7163
# Epoch 1106/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3977 - acc: 0.7349 - val_loss: 4.4520 - val_acc: 0.7167
# Epoch 1107/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.4014 - acc: 0.7362 - val_loss: 4.4515 - val_acc: 0.7155
# Epoch 1108/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3980 - acc: 0.7364 - val_loss: 4.4589 - val_acc: 0.7146
# Epoch 1109/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3989 - acc: 0.7349 - val_loss: 4.4604 - val_acc: 0.7153
# Epoch 1110/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3972 - acc: 0.7347 - val_loss: 4.4587 - val_acc: 0.7152
# Epoch 1111/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3952 - acc: 0.7358 - val_loss: 4.4631 - val_acc: 0.7155
# Epoch 1112/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3927 - acc: 0.7350 - val_loss: 4.4628 - val_acc: 0.7134
# Epoch 1113/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3990 - acc: 0.7345 - val_loss: 4.4547 - val_acc: 0.7149
# Epoch 1114/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3950 - acc: 0.7346 - val_loss: 4.4612 - val_acc: 0.7155
# Epoch 1115/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3860 - acc: 0.7341 - val_loss: 4.4631 - val_acc: 0.7144
# Epoch 1116/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3990 - acc: 0.7362 - val_loss: 4.4588 - val_acc: 0.7152
# Epoch 1117/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3854 - acc: 0.7367 - val_loss: 4.4586 - val_acc: 0.7150
# Epoch 1118/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3899 - acc: 0.7358 - val_loss: 4.4654 - val_acc: 0.7137
# Epoch 1119/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3867 - acc: 0.7369 - val_loss: 4.4589 - val_acc: 0.7154
# Epoch 1120/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3873 - acc: 0.7355 - val_loss: 4.4583 - val_acc: 0.7166
# Epoch 1121/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3991 - acc: 0.7362 - val_loss: 4.4639 - val_acc: 0.7147
# Epoch 1122/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3888 - acc: 0.7353 - val_loss: 4.4627 - val_acc: 0.7147
# Epoch 1123/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3910 - acc: 0.7366 - val_loss: 4.4635 - val_acc: 0.7146
# Epoch 1124/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3939 - acc: 0.7348 - val_loss: 4.4572 - val_acc: 0.7159
# Epoch 1125/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.3943 - acc: 0.7359 - val_loss: 4.4588 - val_acc: 0.7148
# Epoch 1126/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3859 - acc: 0.7359 - val_loss: 4.4655 - val_acc: 0.7153
# Epoch 1127/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3829 - acc: 0.7350 - val_loss: 4.4622 - val_acc: 0.7156
# Epoch 1128/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3874 - acc: 0.7367 - val_loss: 4.4573 - val_acc: 0.7164
# Epoch 1129/1200
# 28/28 [==============================] - 1s 29ms/step - loss: 4.3884 - acc: 0.7366 - val_loss: 4.4625 - val_acc: 0.7151
# Epoch 1130/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.3809 - acc: 0.7355 - val_loss: 4.4659 - val_acc: 0.7170
# Epoch 1131/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3906 - acc: 0.7364 - val_loss: 4.4550 - val_acc: 0.7162
# Epoch 1132/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.3830 - acc: 0.7374 - val_loss: 4.4580 - val_acc: 0.7150
# Epoch 1133/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3847 - acc: 0.7353 - val_loss: 4.4572 - val_acc: 0.7159
# Epoch 1134/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3817 - acc: 0.7366 - val_loss: 4.4611 - val_acc: 0.7149
# Epoch 1135/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3914 - acc: 0.7346 - val_loss: 4.4591 - val_acc: 0.7168
# Epoch 1136/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 4.3845 - acc: 0.7366 - val_loss: 4.4593 - val_acc: 0.7157
# Epoch 1137/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3831 - acc: 0.7358 - val_loss: 4.4607 - val_acc: 0.7155
# Epoch 1138/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 4.3879 - acc: 0.7353 - val_loss: 4.4567 - val_acc: 0.7166
# Epoch 1139/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 4.3759 - acc: 0.7386 - val_loss: 4.4582 - val_acc: 0.7150
# Epoch 1140/1200
# 28/28 [==============================] - 1s 26ms/step - loss: 4.3799 - acc: 0.7356 - val_loss: 4.4612 - val_acc: 0.7160
# Epoch 1141/1200
# 28/28 [==============================] - 1s 33ms/step - loss: 4.3796 - acc: 0.7363 - val_loss: 4.4584 - val_acc: 0.7159
# Epoch 1142/1200
# 28/28 [==============================] - 1s 28ms/step - loss: 4.3736 - acc: 0.7355 - val_loss: 4.4592 - val_acc: 0.7157
# Epoch 1143/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.3828 - acc: 0.7368 - val_loss: 4.4557 - val_acc: 0.7150
# Epoch 1144/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3726 - acc: 0.7354 - val_loss: 4.4552 - val_acc: 0.7153
# Epoch 1145/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3773 - acc: 0.7366 - val_loss: 4.4588 - val_acc: 0.7151
# Epoch 1146/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3801 - acc: 0.7363 - val_loss: 4.4556 - val_acc: 0.7143
# Epoch 1147/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3795 - acc: 0.7368 - val_loss: 4.4621 - val_acc: 0.7156
# Epoch 1148/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3809 - acc: 0.7367 - val_loss: 4.4614 - val_acc: 0.7152
# Epoch 1149/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3812 - acc: 0.7365 - val_loss: 4.4569 - val_acc: 0.7145
# Epoch 1150/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3723 - acc: 0.7367 - val_loss: 4.4567 - val_acc: 0.7168
# Epoch 1151/1200
# 28/28 [==============================] - 1s 22ms/step - loss: 4.3794 - acc: 0.7358 - val_loss: 4.4561 - val_acc: 0.7160
# Epoch 1152/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3751 - acc: 0.7380 - val_loss: 4.4601 - val_acc: 0.7175
# Epoch 1153/1200
# 28/28 [==============================] - 1s 25ms/step - loss: 4.3776 - acc: 0.7356 - val_loss: 4.4560 - val_acc: 0.7160
# Epoch 1154/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3713 - acc: 0.7378 - val_loss: 4.4557 - val_acc: 0.7161
# Epoch 1155/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 4.3734 - acc: 0.7379 - val_loss: 4.4592 - val_acc: 0.7151
# Epoch 1156/1200
# 28/28 [==============================] - 1s 23ms/step - loss: 4.3671 - acc: 0.7368 - val_loss: 4.4637 - val_acc: 0.7157
# Epoch 1157/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3797 - acc: 0.7359 - val_loss: 4.4599 - val_acc: 0.7155
# Epoch 1158/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3787 - acc: 0.7358 - val_loss: 4.4561 - val_acc: 0.7148
# Epoch 1159/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 4.3765 - acc: 0.7378 - val_loss: 4.4569 - val_acc: 0.7166
# Epoch 1160/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 4.3716 - acc: 0.7387 - val_loss: 4.4620 - val_acc: 0.7153
# Epoch 1161/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3784 - acc: 0.7347 - val_loss: 4.4592 - val_acc: 0.7157
# Epoch 1162/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3704 - acc: 0.7372 - val_loss: 4.4584 - val_acc: 0.7162
# Epoch 1163/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3812 - acc: 0.7359 - val_loss: 4.4541 - val_acc: 0.7159
# Epoch 1164/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3729 - acc: 0.7372 - val_loss: 4.4545 - val_acc: 0.7146
# Epoch 1165/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3722 - acc: 0.7385 - val_loss: 4.4558 - val_acc: 0.7160
# Epoch 1166/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3717 - acc: 0.7361 - val_loss: 4.4599 - val_acc: 0.7152
# Epoch 1167/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3703 - acc: 0.7371 - val_loss: 4.4570 - val_acc: 0.7158
# Epoch 1168/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3683 - acc: 0.7368 - val_loss: 4.4588 - val_acc: 0.7158
# Epoch 1169/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3687 - acc: 0.7371 - val_loss: 4.4567 - val_acc: 0.7172
# Epoch 1170/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3686 - acc: 0.7378 - val_loss: 4.4554 - val_acc: 0.7166
# Epoch 1171/1200
# 28/28 [==============================] - 1s 30ms/step - loss: 4.3672 - acc: 0.7372 - val_loss: 4.4549 - val_acc: 0.7153
# Epoch 1172/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3700 - acc: 0.7378 - val_loss: 4.4535 - val_acc: 0.7145
# Epoch 1173/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 4.3704 - acc: 0.7378 - val_loss: 4.4536 - val_acc: 0.7155
# Epoch 1174/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3686 - acc: 0.7377 - val_loss: 4.4557 - val_acc: 0.7141
# Epoch 1175/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3698 - acc: 0.7366 - val_loss: 4.4564 - val_acc: 0.7157
# Epoch 1176/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3676 - acc: 0.7375 - val_loss: 4.4528 - val_acc: 0.7167
# Epoch 1177/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3707 - acc: 0.7367 - val_loss: 4.4587 - val_acc: 0.7164
# Epoch 1178/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3725 - acc: 0.7362 - val_loss: 4.4566 - val_acc: 0.7162
# Epoch 1179/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3619 - acc: 0.7389 - val_loss: 4.4534 - val_acc: 0.7156
# Epoch 1180/1200
# 28/28 [==============================] - 1s 20ms/step - loss: 4.3723 - acc: 0.7367 - val_loss: 4.4538 - val_acc: 0.7166
# Epoch 1181/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3751 - acc: 0.7373 - val_loss: 4.4606 - val_acc: 0.7163
# Epoch 1182/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3700 - acc: 0.7370 - val_loss: 4.4569 - val_acc: 0.7170
# Epoch 1183/1200
# 28/28 [==============================] - 1s 21ms/step - loss: 4.3633 - acc: 0.7382 - val_loss: 4.4498 - val_acc: 0.7169
# Epoch 1184/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3618 - acc: 0.7385 - val_loss: 4.4542 - val_acc: 0.7151
# Epoch 1185/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 4.3630 - acc: 0.7372 - val_loss: 4.4583 - val_acc: 0.7148
# Epoch 1186/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3678 - acc: 0.7373 - val_loss: 4.4571 - val_acc: 0.7154
# Epoch 1187/1200
# 28/28 [==============================] - 1s 24ms/step - loss: 4.3628 - acc: 0.7374 - val_loss: 4.4554 - val_acc: 0.7151
# Epoch 1188/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3602 - acc: 0.7392 - val_loss: 4.4534 - val_acc: 0.7157
# Epoch 1189/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3607 - acc: 0.7394 - val_loss: 4.4569 - val_acc: 0.7163
# Epoch 1190/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3632 - acc: 0.7383 - val_loss: 4.4598 - val_acc: 0.7160
# Epoch 1191/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3618 - acc: 0.7383 - val_loss: 4.4549 - val_acc: 0.7149
# Epoch 1192/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3603 - acc: 0.7374 - val_loss: 4.4589 - val_acc: 0.7170
# Epoch 1193/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3658 - acc: 0.7381 - val_loss: 4.4566 - val_acc: 0.7158
# Epoch 1194/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3608 - acc: 0.7373 - val_loss: 4.4579 - val_acc: 0.7156
# Epoch 1195/1200
# 28/28 [==============================] - 0s 18ms/step - loss: 4.3664 - acc: 0.7382 - val_loss: 4.4540 - val_acc: 0.7157
# Epoch 1196/1200
# 28/28 [==============================] - 1s 19ms/step - loss: 4.3585 - acc: 0.7387 - val_loss: 4.4581 - val_acc: 0.7173
# Epoch 1197/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3638 - acc: 0.7387 - val_loss: 4.4601 - val_acc: 0.7157
# Epoch 1198/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3571 - acc: 0.7390 - val_loss: 4.4513 - val_acc: 0.7156
# Epoch 1199/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3592 - acc: 0.7372 - val_loss: 4.4516 - val_acc: 0.7153
# Epoch 1200/1200
# 28/28 [==============================] - 1s 18ms/step - loss: 4.3554 - acc: 0.7391 - val_loss: 4.4505 - val_acc: 0.7167

# %%
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %%
windowSize = 100
hour = 3
hour = min(hour, forecast_horizon)
print(f"Hours ahead = {hour}")
# Out:
# Hours ahead = 3

# %%
def getLabelArrays(hour, input_sequence_length=input_sequence_length):
    syncindex = input_sequence_length + hour - 1
    yTestPred = model.predict(test_dataset, verbose=0)
    ypredFull = yTestPred[:windowSize, hour-1, :,:]
    yactualFull = Ytest[syncindex:windowSize+syncindex:, :]
    mae1 = mean_absolute_error(ypredFull[:,:,0], yactualFull[:,:,0])
    mae2 = mean_absolute_error(ypredFull[:,:,1], yactualFull[:,:,1])

    return ypredFull, yactualFull, mae1, mae2


def plotComparison(airport_index, hour):
    ypredFull, yactualFull, _, _ = getLabelArrays(hour)
    fig, axs = plt.subplots(2, 1, sharex=True, num=airport_index)
    axs[0].plot(yactualFull[:, 0 + airport_index, 0], label="Actual Arrival Delay")
    axs[1].plot(yactualFull[:, airport_index, 1], label="Actual Departure Delay")
    axs[0].plot(ypredFull[:, 0 + airport_index, 0], label="Predicted Arrival Delay")
    axs[1].plot(ypredFull[:, airport_index, 1], label="Predicted Departure Delay")
    axs[0].legend()
    # axs[1].legend()
    axs[1].set_xlabel("Time (hours)")
    axs[0].set_ylabel("Arrival Delay (mins)")
    axs[1].set_ylabel("Departure Delay (mins)")
    plt.suptitle(f"Comparison for: {airports[airport_index]}. Forward: {hour}h, Backward: {hour}h")


def plotMAEOverTime(forecast_horizon=forecast_horizon):
    hours = list(range(1, forecast_horizon+1))
    maeList = []
    maeList2 = []
    for h in hours:
        _,_, mae1, mae2 = getLabelArrays(h)
        maeList.append(mae1)
        maeList2.append(mae2)
    plt.plot(hours, maeList)
    plt.plot(hours, maeList2)
    plt.xlabel("Look forward (hours)")
    plt.ylabel("MAE (minutes)")


plotMAEOverTime()
plt.show()

for airportidx in range(0, len(airports)):
    plotComparison(airportidx, hour)
# plt.show()

# %%
# P = generateKeplerAirports(airports, start, end, timeslotLength, [3,6,9,12], val_idx+14, yTestPred[:,0,:] , Ytest[14:])

# time_test = start + timedelta(timeslotLength*(val_idx+14))

# Q = generateKeplerFlightsMultiple(airports, time_test, end, timeslotLength, save_to_csv= True)

# %% [markdown]
# ## Add logbook to tensorboard

# %%
# !tensorboard dev upload --logdir ./logs \
#   --name "Tuning model 2" \
#   --description "Trying some stuff ans last run on TOP50"\
#   --one_shot

# %%
# a = np.asarray(Ytest[14:])
# np.savetxt("actualy.csv", a, delimiter=",")

print(start+timedelta(minutes=timeslotLength*(val_idx+45)))
# Out:
# 2018-06-14 13:00:00
