# %%
import pandas as pd

# %%
df = pd.read_parquet("data/all_flights.parquet")

# %%
df_ = df.eval("km=distance_nm*1.852")

# %%
df_.query("km<200").shape[0] * 3
# Out:
# 1243626

# %%
df_.shape[0] * 3
# Out:
# 40065375

# %%
df.query(
    f'{qtl["delay_arrival"][0.001]}<delay_arrival<{qtl["delay_arrival"][0.999]}'
).query(
    f'{qtl["delay_departure"][0.001]}<delay_departure<{qtl["delay_departure"][0.999]}'
)[
    ["delay_arrival", "delay_departure"]
].plot(
    kind="box"
)
# Out:
# <Axes: >
