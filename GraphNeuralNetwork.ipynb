# %%
import spektral
from graphnn import *
from extraction.extractionvalues import *

# %%
airports = ICAOTOP50

# %%
graphData = datasets.FlightNetworkDataset(airports, timeslotLength=5)
# Out:
# 100%|██████████| 50/50 [00:01<00:00, 26.05it/s]

# %%
graphData.visualiseGraph(8)
# Out:
# Plotted time is: ['2019-03-01T00:40:00.000000000']
