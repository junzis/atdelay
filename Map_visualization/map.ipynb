# %%
import folium
import pandas as pd
from extraction.extractionvalues import *

# %%
def readCSV(saveFolder: str = "LRData", fileName: str = "LRDATA.csv"):
    """Read data from a flights dataframe in linear regression format

    Args:
        saveFolder (str, optional): folder where data is saved. Defaults to "LRData".
        fileName (str, optional): filename of the dataset. Defaults to "LRDATA.csv".

    Returns:
        pd.Dataframe: flights dataframe in linear regression format
    """
    fullfilename = f"{saveFolder}/{fileName}"
    P = pd.read_csv(fullfilename, header=0, index_col=0)
    return P


# def remove_duplicate_connections(dataframe):

#     connections_lst = []
    
#     for row in dataframe.iterrows():
#         con1 = row['ADEP']
#         con2 = row['ADES']
#         if con1 < con2 and not((con1, con2) in connections_lst):
#             connections_lst.append((con1, con2))

#         if con1 > con2 and not((con2, con1) in connections_lst):
#             connections_lst.append((con1, con2))

#     df = df.drop(df[<some boolean condition>].index)

# %%
# Create the map
try:
    map = folium.Map(location=[55, 17], zoom_start=4,
                    tiles='https://tiles.stadiamaps.com/tiles/outdoors/{z}/{x}/{y}{r}.png?api_key=9d87b5f8-7ecb-4c7f-8e3b-3cf566dba241',
                    attr='&copy; <a href="https://stadiamaps.com/">Stadia Maps</a>, &copy; <a href="https://openmaptiles.org/">OpenMapTiles</a> &copy; <a href="http://openstreetmap.org">OpenStreetMap</a> contributors',
                    )
except:
    map = folium.Map(location=[55, 17], zoom_start=4, tiles='CartoDB positron')


airports_locations = readCSV("filteredData", "airportlocations.csv")
airports_connections = readCSV("filteredData", "airportcombinations.csv")
not_plotted = ['LTFM', 'UUEE']

# Plot the airports (Nodes)

for _, airport in airports_locations.iterrows():
    if airport['code'] in ICAOTOP10 and not(airport['code'] in not_plotted):
        folium.Marker(
        [airport['longitude'], airport['latitude']],
        popup=airport['code'],
        icon=folium.Icon(icon="plane")
        ).add_to(map)


# Plot the connections (edges)



airports_connections



i = 0
for _, connection in airports_connections.iterrows():
    # if connection['ADEP'] == 'EHAM' or connection['ADES'] == 'EHAM':
    # if connection['count'] > 5:
    if connection['ADES'] in ICAOTOP10 and connection['ADEP'] in ICAOTOP10 and not(connection['ADES'] in not_plotted) and not(connection['ADEP'] in not_plotted):
        folium.PolyLine([(connection['ADEPLat'], connection['ADEPLong']), (connection['ADESLat'], connection['ADESLong'])],
        popup=connection['count'],
        tooltip =f'{connection["ADEP"]}-{connection["ADES"]}'
        ).add_to(map)

map.save('small_map.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
